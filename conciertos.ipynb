# %%
import pandas as pd
pd.set_option('display.max_rows', None)
from numpy import where

# %% [markdown]
# ### Loop the data lines
# for file_number in range(1, 23+1):
#     with open('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', 'r') as temp_f:
#         # get No of columns in each line
#         col_count = [ len(l.split(",")) for l in temp_f.readlines() ]
#
#     ### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
#     column_names = ['COLUMN_'+str(i) for i in range(0, max(col_count))]
#
#     ### Read csv
#     df = pd.read_csv('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', header=None, delimiter=",", names=column_names)
#
#     df = df.drop(0)
#
#     df['COLUMN_12'] = df.query("not COLUMN_11.isnull()")['COLUMN_5'] + " " + df.query("not COLUMN_11.isnull()")['COLUMN_4'].str.replace('\\', '')
#     df['COLUMN_12'] = df['COLUMN_12'].str.replace('_', '\'')
#     df['COLUMN_4'] = where(df['COLUMN_12'].isnull(), df['COLUMN_4'], df['COLUMN_12'])
#
#     df['COLUMN_5'] = where(df['COLUMN_12'].isnull(), df['COLUMN_5'], df['COLUMN_6'])
#     df['COLUMN_6'] = where(df['COLUMN_12'].isnull(), df['COLUMN_6'], df['COLUMN_7'])
#     df['COLUMN_7'] = where(df['COLUMN_12'].isnull(), df['COLUMN_7'], df['COLUMN_8'])
#     df['COLUMN_8'] = where(df['COLUMN_12'].isnull(), df['COLUMN_8'], df['COLUMN_9'])
#     df['COLUMN_9'] = where(df['COLUMN_12'].isnull(), df['COLUMN_9'], df['COLUMN_10'])
#     df['COLUMN_10'] = where(df['COLUMN_12'].isnull(), df['COLUMN_10'], df['COLUMN_11'])
#     df.drop(columns=['COLUMN_11', 'COLUMN_12'], inplace=True)
#
#     df = df.rename(columns={'COLUMN_0': 'gira','COLUMN_1': 'interprete', 'COLUMN_2': 'fecha', 'COLUMN_3': 'lugar', 'COLUMN_4': 'pais', 'COLUMN_5': 'duracion_total', 'COLUMN_6': 'orden', 'COLUMN_7': 'tema', 'COLUMN_8': 'pasaporte_autor', 'COLUMN_9': 'autor', 'COLUMN_10': 'duracion'})
#
#     df.to_csv('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'_filtered.csv')

# %%
for file_number in range(23, 23+1):
    with open('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', 'r') as temp_f:
        # get No of columns in each line
        col_count = [ len(l.split(",")) for l in temp_f.readlines() ]

    ### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
    column_names = ['COLUMN_'+str(i) for i in range(0, max(col_count))]

    ### Read csv
    df = pd.read_csv('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', header=None, delimiter=",", names=column_names)

    df = df.drop(0)

    df['COLUMN_12'] = df.query("not COLUMN_11.isnull()")['COLUMN_5'] + " " + df.query("not COLUMN_11.isnull()")['COLUMN_4'].str.replace('\\', '')
    df['COLUMN_12'] = df['COLUMN_12'].str.replace('_', '\'')
    df['COLUMN_4'] = where(df['COLUMN_12'].isnull(), df['COLUMN_4'], df['COLUMN_12'])

    df['COLUMN_5'] = where(df['COLUMN_12'].isnull(), df['COLUMN_5'], df['COLUMN_6'])
    df['COLUMN_6'] = where(df['COLUMN_12'].isnull(), df['COLUMN_6'], df['COLUMN_7'])
    df['COLUMN_7'] = where(df['COLUMN_12'].isnull(), df['COLUMN_7'], df['COLUMN_8'])
    df['COLUMN_8'] = where(df['COLUMN_12'].isnull(), df['COLUMN_8'], df['COLUMN_9'])
    df['COLUMN_9'] = where(df['COLUMN_12'].isnull(), df['COLUMN_9'], df['COLUMN_10'])
    df['COLUMN_10'] = where(df['COLUMN_12'].isnull(), df['COLUMN_10'], df['COLUMN_11'])
    df.drop(columns=['COLUMN_11', 'COLUMN_12'], inplace=True)
    df = df.rename(columns={'COLUMN_0': 'gira','COLUMN_1': 'interprete', 'COLUMN_2': 'fecha', 'COLUMN_3': 'lugar', 'COLUMN_4': 'pais', 'COLUMN_5': 'duracion_total', 'COLUMN_6': 'orden', 'COLUMN_7': 'tema', 'COLUMN_8': 'pasaporte_autor', 'COLUMN_9': 'autor', 'COLUMN_10': 'duracion'})
    df['pais'] = df['pais'].str.replace('\?land Islands', 'Åland Islands')

    df['gira'] = df['gira'].str.replace('Tourn\?e', 'Tournée')
    df['gira'] = df['gira'].str.replace('lugare\?os', 'lugareños')
    df['gira'] = df['gira'].str.replace('ed\?n', 'edén')
    df['gira'] = df['gira'].str.replace('Carli\?a', 'Carliña')
    df['gira'] = df['gira'].str.replace('cipr\?s', 'ciprés')
    df['gira'] = df['gira'].str.replace('sensaci\?n', 'sensación')
    df['gira'] = df['gira'].str.replace('plut\?n', 'plutón')
    df['gira'] = df['gira'].str.replace('le\?ador', 'leñador')
    df['gira'] = df['gira'].str.replace('mec\?nico', 'mecánico')
    df['gira'] = df['gira'].str.replace('tentaci\?n', 'tentación')
    df['gira'] = df['gira'].str.replace('az\?car', 'azúcar')
    df['gira'] = df['gira'].str.replace('mec\?nic', 'mecánico')
    df['gira'] = df['gira'].str.replace('c\?mo', 'cómo')
    df['gira'] = df['gira'].str.replace('sinton\?a', 'sintonía')
    df['gira'] = df['gira'].str.replace('versi\?n', 'versión')
    df['gira'] = df['gira'].str.replace('d\?a', 'día')
    df['gira'] = df['gira'].str.replace('h\?roe', 'héroe')
    df['gira'] = df['gira'].str.replace('melod\?a', 'melodía')
    df['gira'] = df['gira'].str.replace('televisi\?n', 'televisión')
    df['gira'] = df['gira'].str.replace('coraz\?n', 'corazón')
    df['gira'] = df['gira'].str.replace('ma\?ana', 'mañana')
    df['gira'] = df['gira'].str.replace('Clori\?a', 'Cloriña')
    df['gira'] = df['gira'].str.replace('antesdespu\?s', 'antesdespués')
    df['gira'] = df['gira'].str.replace('\?xito', 'éxito')
    df['gira'] = df['gira'].str.replace('Ma\?anitas', 'Mañanitas')
    df['gira'] = df['gira'].str.replace('Pa\?ez', 'Pañez')
    df['gira'] = df['gira'].str.replace('Domi\?o', 'Domióo')
    df['gira'] = df['gira'].str.replace('\?avincopa', 'Ñavincopa')
    df['gira'] = df['gira'].str.replace('sue\?os', 'sueños')
    df['gira'] = df['gira'].str.replace('Dani\?o', 'Daniño')
    df['gira'] = df['gira'].str.replace('Cig\?e\?ales', 'Cigüeñales')

    df['interprete'] = df['interprete'].str.replace('Carli\?a', 'Carliña')
    df['interprete'] = df['interprete'].str.replace('Clori\?a', 'Cloriña')
    df['interprete'] = df['interprete'].str.replace('Pa\?ez', 'Pañez')
    df['interprete'] = df['interprete'].str.replace('Dani\?o', 'Daniño')
    df['interprete'] = df['interprete'].str.replace('Ma\?anitas', 'Mañanitas')
    df['interprete'] = df['interprete'].str.replace('Domi\?o', 'Domiño')
    df['interprete'] = df['interprete'].str.replace('Cal\?', 'Calí')
    df['interprete'] = df['interprete'].str.replace('\?avincopa', 'Ñavincopa')
    df['interprete'] = df['interprete'].str.replace('Cig\?e\?ales', 'Cigüeñales')

    df['tema'] = df['tema'].str.replace('Tourn\?e', 'Tournée')
    df['tema'] = df['tema'].str.replace('lugare\?os', 'lugareños')
    df['tema'] = df['tema'].str.replace('ed\?n', 'edén')
    df['tema'] = df['tema'].str.replace('Carli\?a', 'Carliña')
    df['tema'] = df['tema'].str.replace('cipr\?s', 'ciprés')
    df['tema'] = df['tema'].str.replace('sensaci\?n', 'sensación')
    df['tema'] = df['tema'].str.replace('plut\?n', 'plutón')
    df['tema'] = df['tema'].str.replace('le\?ador', 'leñador')
    df['tema'] = df['tema'].str.replace('mec\?nico', 'mecánico')
    df['tema'] = df['tema'].str.replace('tentaci\?n', 'tentación')
    df['tema'] = df['tema'].str.replace('az\?car', 'azúcar')
    df['tema'] = df['tema'].str.replace('mec\?nic', 'mecánic')
    df['tema'] = df['tema'].str.replace('c\?mo', 'cómo')
    df['tema'] = df['tema'].str.replace('sinton\?a', 'sintonía')
    df['tema'] = df['tema'].str.replace('versi\?n', 'versión')
    df['tema'] = df['tema'].str.replace('d\?a', 'día')
    df['tema'] = df['tema'].str.replace('h\?roe', 'héroe')
    df['tema'] = df['tema'].str.replace('melod\?a', 'melodía')
    df['tema'] = df['tema'].str.replace('televisi\?n', 'televisión')
    df['tema'] = df['tema'].str.replace('coraz\?n', 'corazón')
    df['tema'] = df['tema'].str.replace('ma\?ana', 'mañana')
    df['tema'] = df['tema'].str.replace('Clori\?a', 'Cloriña')
    df['tema'] = df['tema'].str.replace('antesdespu\?s', 'antesdespués')
    df['tema'] = df['tema'].str.replace('\?xito', 'éxito')
    df['tema'] = df['tema'].str.replace('Ma\?anitas', 'Mañanitas')
    df['tema'] = df['tema'].str.replace('Pa\?ez', 'Pañez')
    df['tema'] = df['tema'].str.replace('Domi\?o', 'Domiño')
    df['tema'] = df['tema'].str.replace('\?avincopa', 'Ñavincopa')
    df['tema'] = df['tema'].str.replace('sue\?os', 'sueños')
    df['tema'] = df['tema'].str.replace('Dani\?o', 'Daniño')
    df['tema'] = df['tema'].str.replace('Cig\?e\?ales', 'Cigüeñales')
    df['tema'] = df['tema'].str.replace('Carli\?a', 'Carliña')
    df['tema'] = df['tema'].str.replace('Clori\?a', 'Cloriña')
    df['tema'] = df['tema'].str.replace('Pa\?ez', 'Pañez')
    df['tema'] = df['tema'].str.replace('Dani\?o', 'Daniño')
    df['tema'] = df['tema'].str.replace('Ma\?anitas', 'Mañanitas')
    df['tema'] = df['tema'].str.replace('Domi\?o', 'Domiño')
    df['tema'] = df['tema'].str.replace('Cal\?', 'Calí')
    df['tema'] = df['tema'].str.replace('\?avincopa', 'Ñavincopa')
    df['tema'] = df['tema'].str.replace('Cig\?e\?ales', 'Cigüeñales')
    df['tema'] = df['tema'].str.replace('Rev\?s', 'Revés')
    df['tema'] = df['tema'].str.replace('Televisi\?n', 'Televisión')
    df['tema'] = df['tema'].str.replace('\?rbol', 'árbol')
    df['tema'] = df['tema'].str.replace('para\?so', 'paraíso')
    df['tema'] = df['tema'].str.replace('J\?piter', 'Júpiter')
    df['tema'] = df['tema'].str.replace('So\?ador', 'Soñador')
    df['tema'] = df['tema'].str.replace('se\?ora', 'señora')
    df['tema'] = df['tema'].str.replace('le\?ador', 'leñador')
    df['tema'] = df['tema'].str.replace('sensaci\?n', 'sensación')
    df['tema'] = df['tema'].str.replace('mec\?nica', 'mecánica')
    df['tema'] = df['tema'].str.replace('Discusi\?n', 'Discusión')
    df['tema'] = df['tema'].str.replace('Melod\?a', 'Melodía')
    df['tema'] = df['tema'].str.replace('t\?nel', 'túnel')
    df['tema'] = df['tema'].str.replace('Az\?car', 'Azúcar')
    df['tema'] = df['tema'].str.replace('Monta\?as', 'Montañas')
    df['tema'] = df['tema'].str.replace('\?rbol', 'árbol')
    df['tema'] = df['tema'].str.replace('celebraci\?n', 'celebración')
    df['tema'] = df['tema'].str.replace('coraz\?n', 'corazón')
    df['tema'] = df['tema'].str.replace('cipr\?s', 'ciprés')
    df['tema'] = df['tema'].str.replace('Melod\?a de versi\?n', 'Melodía de versión')
    df['tema'] = df['tema'].str.replace('h\?roe', 'héroe')
    df['tema'] = df['tema'].str.replace('Rel\?mpago', 'Relámpago')
    df['tema'] = df['tema'].str.replace('J\?piter', 'Júpiter')
    df['tema'] = df['tema'].str.replace('c\?mo', 'cómo')
    df['tema'] = df['tema'].str.replace('televisi\?n', 'televisión')
    df['tema'] = df['tema'].str.replace('Due\?a', 'Dueña')
    df['tema'] = df['tema'].str.replace('Popurr\?', 'Popurrí')
    df['tema'] = df['tema'].str.replace('m\?sica', 'música')
    df['tema'] = df['tema'].str.replace('C\?mo', 'Cómo')
    df['tema'] = df['tema'].str.replace('Estaci\?n', 'Estación')
    df['tema'] = df['tema'].str.replace('Cipr\?s', 'Ciprés')
    df['tema'] = df['tema'].str.replace('televisi\?n', 'televisión')
    df['tema'] = df['tema'].str.replace('P\?jaro', 'Pájaro')
    df['tema'] = df['tema'].str.replace('m\?sica', 'música')
    df['tema'] = df['tema'].str.replace('M\?sica', 'Música')
    df['tema'] = df['tema'].str.replace('ed\?n', 'edén')
    df['tema'] = df['tema'].str.replace('J\?piter', 'Júpiter')
    df['tema'] = df['tema'].str.replace('le\?ador', 'leñador')
    df['tema'] = df['tema'].str.replace('lugare\?os', 'lugareños')
    df['tema'] = df['tema'].str.replace('Caser\?o', 'Caserío')
    df['tema'] = df['tema'].str.replace('h\?roe', 'héroe')
    df['tema'] = df['tema'].str.replace('c\?mo', 'cómo')
    df['tema'] = df['tema'].str.replace('Melod\?a', 'Melodía')
    df['tema'] = df['tema'].str.replace('coraz\?n', 'corazón')
    df['tema'] = df['tema'].str.replace('Az\?car', 'Azúcar')
    df['tema'] = df['tema'].str.replace('Ni\?os', 'Niños')
    df['tema'] = df['tema'].str.replace('P\?jaro', 'Pájaro')
    df['tema'] = df['tema'].str.replace('cipr\?s', 'ciprés')
    df['tema'] = df['tema'].str.replace('se\?or', 'señor')
    df['tema'] = df['tema'].str.replace('mu\?eco', 'muñeco')
    df['tema'] = df['tema'].str.replace('Sinton\?a', 'Sintonía')
    df['tema'] = df['tema'].str.replace('bodeg\?n', 'bodegón')
    df['tema'] = df['tema'].str.replace('Tentaci\?n', 'Tentación')
    df['tema'] = df['tema'].str.replace('Celebraci\?n', 'Celebración')
    df['tema'] = df['tema'].str.replace('\?ltimo', 'Último')
    df['tema'] = df['tema'].str.replace('Lugare\?os', 'Lugareños')
    df['tema'] = df['tema'].str.replace('F\?tbol', 'Fútbol')
    df['tema'] = df['tema'].str.replace('\?ltimo', 'Último')
    df['tema'] = df['tema'].str.replace('extra\?o', 'extraño')
    df['tema'] = df['tema'].str.replace('Caf\? nueva', 'Café nueva')
    df['tema'] = df['tema'].str.replace('Versi\?n', 'Versión')
    df['tema'] = df['tema'].str.replace('rev\?s', 'revés')
    df['tema'] = df['tema'].str.replace('Se\?or', 'Señor')
    df['tema'] = df['tema'].str.replace('Caf\? de promesa', 'Café de promesa')
    df['tema'] = df['tema'].str.replace('\?ltimo piel', 'Último piel')
    df['tema'] = df['tema'].str.replace('D\?a boina', 'Día boina')
    df['tema'] = df['tema'].str.replace('cig\?e\?a', 'cigüeña')
    df['tema'] = df['tema'].str.replace('Claveles y cig\?e\?a', 'Claveles y cigüeña')
    df['tema'] = df['tema'].str.replace('Tentaci\?n o silencio', 'Tentación o silencio')
    df['tema'] = df['tema'].str.replace('Piedras p\?jaro', 'Piedras pájaro')
    df['tema'] = df['tema'].str.replace('Respirar o sauces \(ac\?stico\)', 'Respirar o sauces (acústico)')
    df['tema'] = df['tema'].str.replace('Qui\?n cestero', 'Quién cestero')
    df['tema'] = df['tema'].str.replace('Alas o \?ltimo', 'Alas o último')
    df['tema'] = df['tema'].str.replace('Discusion y caser\?o', 'Discusión y caserío')
    df['tema'] = df['tema'].str.replace('Mec\?nico', 'Mecánico')
    df['tema'] = df['tema'].str.replace('Sue\?o', 'Sueño')
    df['tema'] = df['tema'].str.replace('discusi\?n', 'discusión')
    df['tema'] = df['tema'].str.replace('caser\?o', 'caserío')
    df['tema'] = df['tema'].str.replace('Perd\?n', 'Perdón')
    df['tema'] = df['tema'].str.replace('rel\?mpago', 'relámpago')
    df['tema'] = df['tema'].str.replace('Operaci\?n', 'Operación')
    df['tema'] = df['tema'].str.replace('Loco o cig\?e?a', 'Loco o cigüeña')
    df['tema'] = df['tema'].str.replace('Sue\?o pollo', 'Sueño pollo')
    df['tema'] = df['tema'].str.replace('Venus de permanente \(ac\?stico\)', 'Venus de permanente (acústico)')
    df['tema'] = df['tema'].str.replace('Adi\?s o coyote', 'Adiós o coyote')
    df['tema'] = df['tema'].str.replace('Mec\?nico y recuerdos', 'Mecánico y recuerdos')
    df['tema'] = df['tema'].str.replace('Lejan?a y amapolas', 'Lejanía y amapolas')
    df['tema'] = df['tema'].str.replace('Cazador de adi?s', 'Cazador de adiós')
    df['tema'] = df['tema'].str.replace('Equivocado de caser?o', 'Equivocado de caserío')
    df['tema'] = df['tema'].str.replace('Mezcla o qui\?n', 'Mezcla o quién')
    df['tema'] = df['tema'].str.replace('Adi\?s y ermitas', 'Adiós y ermitas')
    df['tema'] = df['tema'].str.replace('Tequila perd?n', 'Tequila perdón')
    df['tema'] = df['tema'].str.replace('Plut\?n y senda', 'Plutón y senda')
    df['tema'] = df['tema'].str.replace('Justicia o adi\?s', 'Justicia o adiós')
    df['tema'] = df['tema'].str.replace('arbol   y popurr\?', 'arbol y popurrí')
    df['tema'] = df['tema'].str.replace('Verdad o due\?a', 'Verdad o dueña')
    df['tema'] = df['tema'].str.replace('bodeg\?n', 'bodegón')
    df['tema'] = df['tema'].str.replace('sinton\?a', 'sintonía')
    df['tema'] = df['tema'].str.replace('ficci\?n', 'ficción')
    df['tema'] = df['tema'].str.replace('Mec\?nico', 'Mecánico')
    df['tema'] = df['tema'].str.replace('\?ltimo', 'Último')
    df['tema'] = df['tema'].str.replace('Adi\?s', 'Adiós')
    df['tema'] = df['tema'].str.replace('Ma\?ana', 'Mañana')
    df['tema'] = df['tema'].str.replace('fantas\?a', 'fantasma')
    df['tema'] = df['tema'].str.replace('operaci\?n', 'operación')
    df['tema'] = df['tema'].str.replace('so\?ador', 'soñador')
    df['tema'] = df['tema'].str.replace('Caf\?', 'Café')
    df['tema'] = df['tema'].str.replace('estaci\?n', 'estación')
    df['tema'] = df['tema'].str.replace('monta\?as', 'montañas')
    df['tema'] = df['tema'].str.replace('discusi\?n', 'discusión')
    df['tema'] = df['tema'].str.replace('H\?roe', 'Héroe')
    df['tema'] = df['tema'].str.replace('Se\?or', 'Señor')
    df['tema'] = df['tema'].str.replace('ac\?stico', 'acústico')
    df['tema'] = df['tema'].str.replace('Bodeg\?n', 'Bodegón')
    df['tema'] = df['tema'].str.replace('perd\?n', 'perdón')
    df['tema'] = df['tema'].str.replace('Para\?so', 'Paraíso')
    df['tema'] = df['tema'].str.replace('T\?nel', 'Túnel')
    df['tema'] = df['tema'].str.replace('f\?tbol', 'fútbol')
    df['tema'] = df['tema'].str.replace('Lejan\?a', 'Lejanía')
    df['tema'] = df['tema'].str.replace('Coraz\?n', 'Corazón')
    df['tema'] = df['tema'].str.replace('sue\?o', 'sueño')
    df['tema'] = df['tema'].str.replace('Le\?ador', 'Leñador')
    df['tema'] = df['tema'].str.replace('Mu\?eco', 'Muñeco')
    df['tema'] = df['tema'].str.replace('Duende y popurr\?', 'Duende y popurrí')
    df['tema'] = df['tema'].str.replace('D\?a o balada', 'Día o balada')
    df['tema'] = df['tema'].str.replace('j\?piter', 'júpiter')
    df['tema'] = df['tema'].str.replace('D\?a y orden', 'Día y orden')
    df['tema'] = df['tema'].str.replace('Fantas\?a', 'Fantasía')
    df['tema'] = df['tema'].str.replace('adi\?s', 'adiós')
    df['tema'] = df['tema'].str.replace('Tequila perd\?n', 'Tequila perdón')
    df['tema'] = df['tema'].str.replace('T\?nel o necesidad', 'Túnel o necesidad')
    df['tema'] = df['tema'].str.replace('Extra\?o', 'Extraño')
    df['tema'] = df['tema'].str.replace('T\?nel de qui\?n', 'Túnel de quién')
    df['tema'] = df['tema'].str.replace('Ficci\?n', 'Ficción')
    df['tema'] = df['tema'].str.replace('Plut\?n', 'Plutón')
    df['tema'] = df['tema'].str.replace('Bodeg\?n', 'Bodegón')
    df['tema'] = df['tema'].str.replace('adi\?s', 'adiós')
    df['tema'] = df['tema'].str.replace('lejan\?a', 'lejanía')
    df['tema'] = df['tema'].str.replace('p\?jaro', 'pájaro')
    df['tema'] = df['tema'].str.replace('Mu\?eco', 'Muñeco')
    df['tema'] = df['tema'].str.replace('Sult\?n', 'Sultán')
    df['tema'] = df['tema'].str.replace('Ficci\?n', 'Ficción')
    df['tema'] = df['tema'].str.replace('Sensaci\?n', 'Sensación')
    df['tema'] = df['tema'].str.replace('Coraz\?n', 'Corazón')
    df['tema'] = df['tema'].str.replace('lejan?a', 'lejanía')
    df['tema'] = df['tema'].str.replace('lejan?a', 'lejanía')
    df['tema'] = df['tema'].str.replace('p\?jaro', 'pájaro')
    df['tema'] = df['tema'].str.replace('Mu\?eco', 'Muñeco')
    df['tema'] = df['tema'].str.replace('Sult\?n', 'Sultán')
    df['tema'] = df['tema'].str.replace('caf\?', 'café')
    df['tema'] = df['tema'].str.replace('Gallinas adi\?s', 'Gallinas adiós')
    df['tema'] = df['tema'].str.replace('Hombre despu\?s', 'Hombre después')
    df['tema'] = df['tema'].str.replace('popurr\?', 'popurrí')
    df['tema'] = df['tema'].str.replace('D\?a', 'Día')
    df['tema'] = df['tema'].str.replace('sult\?n', 'sultán')
    df['tema'] = df['tema'].str.replace('Ed\?n', 'Edén')
    df['tema'] = df['tema'].str.replace('Hombre despu?s', 'Hombre después')
    df['tema'] = df['tema'].str.replace('qui\?n ', 'quién')
    df['tema'] = df['tema'].str.replace('despu\?s', 'después')
    df['tema'] = df['tema'].str.replace('Túnel de qui\?n', 'Túnel de quien')
    df['tema'] = df['tema'].str.replace('Cig\?e', 'Cigüe')
    df['tema'] = df['tema'].str.replace('qui\?n', 'quién')
    df['tema'] = df['tema'].str.replace('ni\?os', 'niños')
    df['tema'] = df['tema'].str.replace('Mec\?nica', 'Mecánica')
    df['tema'] = df['tema'].str.replace('Berl\?n', 'Berlín')
    df['tema'] = df['tema'].str.replace('\?frica', 'África')
    df['tema'] = df['tema'].str.replace('due\?a', 'dueña')
    df['tema'] = df['tema'].str.replace('Qui\?n', 'Quién')
    df['tema'] = df['tema'].str.replace('\?a', 'ña')
    df['tema'] = df['tema'].str.replace('Par\?s', 'París')
    df['tema'] = df['tema'].str.replace('Mosc\?', 'Moscú')
    df['tema'] = df['tema'].str.replace('autob\?s', 'autobús')

    df['autor'] = df['autor'].str.replace('Virgi\?o', 'Virgilio')
    df['autor'] = df['autor'].str.replace('Carli\?a', 'Carlia')
    df['autor'] = df['autor'].str.replace('Due\?as', 'Dueñas')
    df['autor'] = df['autor'].str.replace('Mu\?oz', 'Muñoz')
    df['autor'] = df['autor'].str.replace('Noeli\?a', 'Noelia')
    df['autor'] = df['autor'].str.replace('\?lvarez', 'Álvarez')
    df['autor'] = df['autor'].str.replace('Cloti\?a', 'Clotia')
    df['autor'] = df['autor'].str.replace('Agusti\?o', 'Agustín')
    df['autor'] = df['autor'].str.replace('de la Luna Mu\?iz', 'de la Luna Muñiz')
    df['autor'] = df['autor'].str.replace('de los \?ngeles Mu\?oz', 'de los Ángeles Muñoz')
    df['autor'] = df['autor'].str.replace('Ordo\?ez', 'Ordoñez')
    df['autor'] = df['autor'].str.replace('Daniel Pa\?ez', 'Daniel Páez')
    df['autor'] = df['autor'].str.replace('E.C.\?', 'E.C.Ñ.')
    df['autor'] = df['autor'].str.replace('Ovidi\?a', 'Ovidia')
    df['autor'] = df['autor'].str.replace('Azucena Nu\?ez', 'Azucena Nuñez')
    df['autor'] = df['autor'].str.replace('Clori\?a', 'Cloria')
    df['autor'] = df['autor'].str.replace('Dani\?o', 'Danio')
    df['autor'] = df['autor'].str.replace('Patri\?a', 'Patria')
    df['autor'] = df['autor'].str.replace('Staples \?avincopa', 'Staples Navincopa')
    df['autor'] = df['autor'].str.replace('Domi\?o', 'Dominio')
    df['autor'] = df['autor'].str.replace('Maria de los \?ngeles Muñoz', 'Maria de los Ángeles Muñoz')
    df['autor'] = df['autor'].str.replace('Ag\?ero', 'Agüero')
    df['autor'] = df['autor'].str.replace('Mauri\?a', 'Mauricia')
    df['autor'] = df['autor'].str.replace('Bauti\?o', 'Bautiño')
    df['autor'] = df['autor'].str.replace('\?anez', 'Cáñez')
    df['autor'] = df['autor'].str.replace('\?ngeles', 'Ángeles')
    df['autor'] = df['autor'].str.replace('Verdi\?a', 'Verdía')
    df['autor'] = df['autor'].str.replace('Yuri\?o', 'Yuriño')
    df['autor'] = df['autor'].str.replace('Dari\?o', 'Darío')
    df['autor'] = df['autor'].str.replace('Mu\?ante', 'Muñante')
    df['autor'] = df['autor'].str.replace('\?vila', 'Ávila')
    df['autor'] = df['autor'].str.replace('Prisci\?a', 'Priscila')
    df['autor'] = df['autor'].str.replace('Rodri\?o', 'Rodrigo')
    df['autor'] = df['autor'].str.replace('Placi\?o', 'Placio')
    df['autor'] = df['autor'].str.replace('Berti\?a', 'Bertiza')
    df['autor'] = df['autor'].str.replace('P.P.\?.', 'P.P.A.')
    df['autor'] = df['autor'].str.replace('Elvi\?a', 'Elvia')
    df['autor'] = df['autor'].str.replace('Mari\?o', 'Mariño')

    df['gira'] = df['gira'].str.replace('discusi\?n', 'discusión')
    df['gira'] = df['gira'].str.replace('adi\?s', 'adiós')
    df['gira'] = df['gira'].str.replace('p\?jaro', 'pájaro')
    df['gira'] = df['gira'].str.replace('Lugare\?os', 'Lugareños')
    df['gira'] = df['gira'].str.replace('t\?nel', 'túnel')
    df['gira'] = df['gira'].str.replace('Dari\?o', 'Darío')
    df['gira'] = df['gira'].str.replace('\?vila', 'Ávila')
    df['gira'] = df['gira'].str.replace('Regardotop\?a', 'Regardotopía')
    df['gira'] = df['gira'].str.replace('caser\?o', 'caserío')
    df['gira'] = df['gira'].str.replace('Ag\?ero', 'Agüero')
    df['gira'] = df['gira'].str.replace('qui\?n', 'quién')
    df['gira'] = df['gira'].str.replace('rel\?mpago', 'relámpago')
    df['gira'] = df['gira'].str.replace('se\?ora', 'señora')
    df['gira'] = df['gira'].str.replace('Par\?s', 'París')
    df['gira'] = df['gira'].str.replace('para\?so', 'paraíso')
    df['gira'] = df['gira'].str.replace('estaci\?n', 'estación')
    df['gira'] = df['gira'].str.replace('M\?sica', 'Música')
    df['gira'] = df['gira'].str.replace('Mu\?ante', 'Muñante')
    df['gira'] = df['gira'].str.replace('due\?a', 'dueña')
    df['gira'] = df['gira'].str.replace('monta\?as', 'montañas')
    df['gira'] = df['gira'].str.replace('Due\?as', 'Dueñas')
    df['gira'] = df['gira'].str.replace('extra\?o', 'extraño')
    df['gira'] = df['gira'].str.replace('fantas\?a', 'fantasía')
    df['gira'] = df['gira'].str.replace('\?ltimo', 'último')
    df['gira'] = df['gira'].str.replace('P.P.\?.', 'P.P.A.')
    df['gira'] = df['gira'].str.replace('Mu\?oz', 'Muñoz')
    df['gira'] = df['gira'].str.replace('Mauri\?a', 'Mauricia')
    df['gira'] = df['gira'].str.replace('j\?piter', 'Júpiter')
    df['gira'] = df['gira'].str.replace('Verdi\?a', 'Verdía')
    df['gira'] = df['gira'].str.replace('En\?logos', 'Enólogos')
    df['gira'] = df['gira'].str.replace('se\?or', 'señor')
    df['gira'] = df['gira'].str.replace('lejan\?a', 'lejanía')
    df['gira'] = df['gira'].str.replace('Rodri\?o', 'Rodrigo')
    df['gira'] = df['gira'].str.replace('popurr\?', 'popurrí')
    df['gira'] = df['gira'].str.replace('celebraci\?n', 'celebración')
    df['gira'] = df['gira'].str.replace('caf\?', 'café')

    df['interprete'] = df['interprete'].str.replace('Due\?as', 'Dueñas')
    df['interprete'] = df['interprete'].str.replace('Ag\?ero', 'Agüero')
    df['interprete'] = df['interprete'].str.replace('Mauri\?a', 'Mauricia')
    df['interprete'] = df['interprete'].str.replace('Lugare\?os', 'Lugareños')
    df['interprete'] = df['interprete'].str.replace('P\?jaros', 'Pájaros')
    df['interprete'] = df['interprete'].str.replace('Par\?s', 'París')
    df['interprete'] = df['interprete'].str.replace('Verdi\?a', 'Verdía')
    df['interprete'] = df['interprete'].str.replace('En\?logos', 'Enólogos')
    df['interprete'] = df['interprete'].str.replace('Mu\?ante', 'Muñante')
    df['interprete'] = df['interprete'].str.replace('\?vila', 'Ávila')
    df['interprete'] = df['interprete'].str.replace('Dari\?o', 'Darío')
    df['interprete'] = df['interprete'].str.replace('Rodri\?o', 'Rodrigo')
    df['interprete'] = df['interprete'].str.replace('Regardotop\?a', 'Regardotopía')
    df['interprete'] = df['interprete'].str.replace('P.P.\?.', 'P.P.A.')
    df['interprete'] = df['interprete'].str.replace('Mu\?oz', 'Muñoz')

    if file_number == 18: # csv conciertos_18: 4208731	'86 of devil through the turmoi	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN
        df.loc[4208731] = df.loc[4208730]
        df.loc[4208731]['orden'] = 12  # orden was 11 in previous row

    df['duracion_total'] = df['duracion_total'].astype(int)
    if file_number != 23:
        df['orden'] = df['orden'].astype(int)
        df['duracion'] = df['duracion'].astype(int)
    df.to_csv('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'_filtered.csv', index=False)
# Out:
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_4175/4054330554.py:10: DtypeWarning: Columns (6,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', header=None, delimiter=",", names=column_names)
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_4175/4054330554.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['COLUMN_12'] = df.query("not COLUMN_11.isnull()")['COLUMN_5'] + " " + df.query("not COLUMN_11.isnull()")['COLUMN_4'].str.replace('\\', '')
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_4175/4054330554.py:26: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %%
file_number = 23
with open('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', 'r') as temp_f:
    # get No of columns in each line
    col_count = [ len(l.split(",")) for l in temp_f.readlines() ]

### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
column_names = ['COLUMN_'+str(i) for i in range(0, max(col_count))]

### Read csv
df = pd.read_csv('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', header=None, delimiter=",", names=column_names)

df = df.drop(0)

df['COLUMN_12'] = df.query("not COLUMN_11.isnull()")['COLUMN_5'] + " " + df.query("not COLUMN_11.isnull()")['COLUMN_4'].str.replace('\\', '')
df['COLUMN_12'] = df['COLUMN_12'].str.replace('_', '\'')
df['COLUMN_4'] = where(df['COLUMN_12'].isnull(), df['COLUMN_4'], df['COLUMN_12'])

df['COLUMN_5'] = where(df['COLUMN_12'].isnull(), df['COLUMN_5'], df['COLUMN_6'])
df['COLUMN_6'] = where(df['COLUMN_12'].isnull(), df['COLUMN_6'], df['COLUMN_7'])
df['COLUMN_7'] = where(df['COLUMN_12'].isnull(), df['COLUMN_7'], df['COLUMN_8'])
df['COLUMN_8'] = where(df['COLUMN_12'].isnull(), df['COLUMN_8'], df['COLUMN_9'])
df['COLUMN_9'] = where(df['COLUMN_12'].isnull(), df['COLUMN_9'], df['COLUMN_10'])
df['COLUMN_10'] = where(df['COLUMN_12'].isnull(), df['COLUMN_10'], df['COLUMN_11'])
df.drop(columns=['COLUMN_11', 'COLUMN_12'], inplace=True)
df = df.rename(columns={'COLUMN_0': 'gira','COLUMN_1': 'interprete', 'COLUMN_2': 'fecha', 'COLUMN_3': 'lugar', 'COLUMN_4': 'pais', 'COLUMN_5': 'duracion_total', 'COLUMN_6': 'orden', 'COLUMN_7': 'tema', 'COLUMN_8': 'pasaporte_autor', 'COLUMN_9': 'autor', 'COLUMN_10': 'duracion'})
df['pais'] = df['pais'].str.replace('\?land Islands', 'Åland Islands')

df['gira'] = df['gira'].str.replace('Tourn\?e', 'Tournée')
df['gira'] = df['gira'].str.replace('lugare\?os', 'lugareños')
df['gira'] = df['gira'].str.replace('ed\?n', 'edén')
df['gira'] = df['gira'].str.replace('Carli\?a', 'Carliña')
df['gira'] = df['gira'].str.replace('cipr\?s', 'ciprés')
df['gira'] = df['gira'].str.replace('sensaci\?n', 'sensación')
df['gira'] = df['gira'].str.replace('plut\?n', 'plutón')
df['gira'] = df['gira'].str.replace('le\?ador', 'leñador')
df['gira'] = df['gira'].str.replace('mec\?nico', 'mecánico')
df['gira'] = df['gira'].str.replace('tentaci\?n', 'tentación')
df['gira'] = df['gira'].str.replace('az\?car', 'azúcar')
df['gira'] = df['gira'].str.replace('mec\?nic', 'mecánico')
df['gira'] = df['gira'].str.replace('c\?mo', 'cómo')
df['gira'] = df['gira'].str.replace('sinton\?a', 'sintonía')
df['gira'] = df['gira'].str.replace('versi\?n', 'versión')
df['gira'] = df['gira'].str.replace('d\?a', 'día')
df['gira'] = df['gira'].str.replace('h\?roe', 'héroe')
df['gira'] = df['gira'].str.replace('melod\?a', 'melodía')
df['gira'] = df['gira'].str.replace('televisi\?n', 'televisión')
df['gira'] = df['gira'].str.replace('coraz\?n', 'corazón')
df['gira'] = df['gira'].str.replace('ma\?ana', 'mañana')
df['gira'] = df['gira'].str.replace('Clori\?a', 'Cloriña')
df['gira'] = df['gira'].str.replace('antesdespu\?s', 'antesdespués')
df['gira'] = df['gira'].str.replace('\?xito', 'éxito')
df['gira'] = df['gira'].str.replace('Ma\?anitas', 'Mañanitas')
df['gira'] = df['gira'].str.replace('Pa\?ez', 'Pañez')
df['gira'] = df['gira'].str.replace('Domi\?o', 'Domióo')
df['gira'] = df['gira'].str.replace('\?avincopa', 'Ñavincopa')
df['gira'] = df['gira'].str.replace('sue\?os', 'sueños')
df['gira'] = df['gira'].str.replace('Dani\?o', 'Daniño')
df['gira'] = df['gira'].str.replace('Cig\?e\?ales', 'Cigüeñales')

df['interprete'] = df['interprete'].str.replace('Carli\?a', 'Carliña')
df['interprete'] = df['interprete'].str.replace('Clori\?a', 'Cloriña')
df['interprete'] = df['interprete'].str.replace('Pa\?ez', 'Pañez')
df['interprete'] = df['interprete'].str.replace('Dani\?o', 'Daniño')
df['interprete'] = df['interprete'].str.replace('Ma\?anitas', 'Mañanitas')
df['interprete'] = df['interprete'].str.replace('Domi\?o', 'Domiño')
df['interprete'] = df['interprete'].str.replace('Cal\?', 'Calí')
df['interprete'] = df['interprete'].str.replace('\?avincopa', 'Ñavincopa')
df['interprete'] = df['interprete'].str.replace('Cig\?e\?ales', 'Cigüeñales')

df['tema'] = df['tema'].str.replace('Tourn\?e', 'Tournée')
df['tema'] = df['tema'].str.replace('lugare\?os', 'lugareños')
df['tema'] = df['tema'].str.replace('ed\?n', 'edén')
df['tema'] = df['tema'].str.replace('Carli\?a', 'Carliña')
df['tema'] = df['tema'].str.replace('cipr\?s', 'ciprés')
df['tema'] = df['tema'].str.replace('sensaci\?n', 'sensación')
df['tema'] = df['tema'].str.replace('plut\?n', 'plutón')
df['tema'] = df['tema'].str.replace('le\?ador', 'leñador')
df['tema'] = df['tema'].str.replace('mec\?nico', 'mecánico')
df['tema'] = df['tema'].str.replace('tentaci\?n', 'tentación')
df['tema'] = df['tema'].str.replace('az\?car', 'azúcar')
df['tema'] = df['tema'].str.replace('mec\?nic', 'mecánic')
df['tema'] = df['tema'].str.replace('c\?mo', 'cómo')
df['tema'] = df['tema'].str.replace('sinton\?a', 'sintonía')
df['tema'] = df['tema'].str.replace('versi\?n', 'versión')
df['tema'] = df['tema'].str.replace('d\?a', 'día')
df['tema'] = df['tema'].str.replace('h\?roe', 'héroe')
df['tema'] = df['tema'].str.replace('melod\?a', 'melodía')
df['tema'] = df['tema'].str.replace('televisi\?n', 'televisión')
df['tema'] = df['tema'].str.replace('coraz\?n', 'corazón')
df['tema'] = df['tema'].str.replace('ma\?ana', 'mañana')
df['tema'] = df['tema'].str.replace('Clori\?a', 'Cloriña')
df['tema'] = df['tema'].str.replace('antesdespu\?s', 'antesdespués')
df['tema'] = df['tema'].str.replace('\?xito', 'éxito')
df['tema'] = df['tema'].str.replace('Ma\?anitas', 'Mañanitas')
df['tema'] = df['tema'].str.replace('Pa\?ez', 'Pañez')
df['tema'] = df['tema'].str.replace('Domi\?o', 'Domiño')
df['tema'] = df['tema'].str.replace('\?avincopa', 'Ñavincopa')
df['tema'] = df['tema'].str.replace('sue\?os', 'sueños')
df['tema'] = df['tema'].str.replace('Dani\?o', 'Daniño')
df['tema'] = df['tema'].str.replace('Cig\?e\?ales', 'Cigüeñales')
df['tema'] = df['tema'].str.replace('Carli\?a', 'Carliña')
df['tema'] = df['tema'].str.replace('Clori\?a', 'Cloriña')
df['tema'] = df['tema'].str.replace('Pa\?ez', 'Pañez')
df['tema'] = df['tema'].str.replace('Dani\?o', 'Daniño')
df['tema'] = df['tema'].str.replace('Ma\?anitas', 'Mañanitas')
df['tema'] = df['tema'].str.replace('Domi\?o', 'Domiño')
df['tema'] = df['tema'].str.replace('Cal\?', 'Calí')
df['tema'] = df['tema'].str.replace('\?avincopa', 'Ñavincopa')
df['tema'] = df['tema'].str.replace('Cig\?e\?ales', 'Cigüeñales')
df['tema'] = df['tema'].str.replace('Rev\?s', 'Revés')
df['tema'] = df['tema'].str.replace('Televisi\?n', 'Televisión')
df['tema'] = df['tema'].str.replace('\?rbol', 'árbol')
df['tema'] = df['tema'].str.replace('para\?so', 'paraíso')
df['tema'] = df['tema'].str.replace('J\?piter', 'Júpiter')
df['tema'] = df['tema'].str.replace('So\?ador', 'Soñador')
df['tema'] = df['tema'].str.replace('se\?ora', 'señora')
df['tema'] = df['tema'].str.replace('le\?ador', 'leñador')
df['tema'] = df['tema'].str.replace('sensaci\?n', 'sensación')
df['tema'] = df['tema'].str.replace('mec\?nica', 'mecánica')
df['tema'] = df['tema'].str.replace('Discusi\?n', 'Discusión')
df['tema'] = df['tema'].str.replace('Melod\?a', 'Melodía')
df['tema'] = df['tema'].str.replace('t\?nel', 'túnel')
df['tema'] = df['tema'].str.replace('Az\?car', 'Azúcar')
df['tema'] = df['tema'].str.replace('Monta\?as', 'Montañas')
df['tema'] = df['tema'].str.replace('\?rbol', 'árbol')
df['tema'] = df['tema'].str.replace('celebraci\?n', 'celebración')
df['tema'] = df['tema'].str.replace('coraz\?n', 'corazón')
df['tema'] = df['tema'].str.replace('cipr\?s', 'ciprés')
df['tema'] = df['tema'].str.replace('Melod\?a de versi\?n', 'Melodía de versión')
df['tema'] = df['tema'].str.replace('h\?roe', 'héroe')
df['tema'] = df['tema'].str.replace('Rel\?mpago', 'Relámpago')
df['tema'] = df['tema'].str.replace('J\?piter', 'Júpiter')
df['tema'] = df['tema'].str.replace('c\?mo', 'cómo')
df['tema'] = df['tema'].str.replace('televisi\?n', 'televisión')
df['tema'] = df['tema'].str.replace('Due\?a', 'Dueña')
df['tema'] = df['tema'].str.replace('Popurr\?', 'Popurrí')
df['tema'] = df['tema'].str.replace('m\?sica', 'música')
df['tema'] = df['tema'].str.replace('C\?mo', 'Cómo')
df['tema'] = df['tema'].str.replace('Estaci\?n', 'Estación')
df['tema'] = df['tema'].str.replace('Cipr\?s', 'Ciprés')
df['tema'] = df['tema'].str.replace('televisi\?n', 'televisión')
df['tema'] = df['tema'].str.replace('P\?jaro', 'Pájaro')
df['tema'] = df['tema'].str.replace('m\?sica', 'música')
df['tema'] = df['tema'].str.replace('M\?sica', 'Música')
df['tema'] = df['tema'].str.replace('ed\?n', 'edén')
df['tema'] = df['tema'].str.replace('J\?piter', 'Júpiter')
df['tema'] = df['tema'].str.replace('le\?ador', 'leñador')
df['tema'] = df['tema'].str.replace('lugare\?os', 'lugareños')
df['tema'] = df['tema'].str.replace('Caser\?o', 'Caserío')
df['tema'] = df['tema'].str.replace('h\?roe', 'héroe')
df['tema'] = df['tema'].str.replace('c\?mo', 'cómo')
df['tema'] = df['tema'].str.replace('Melod\?a', 'Melodía')
df['tema'] = df['tema'].str.replace('coraz\?n', 'corazón')
df['tema'] = df['tema'].str.replace('Az\?car', 'Azúcar')
df['tema'] = df['tema'].str.replace('Ni\?os', 'Niños')
df['tema'] = df['tema'].str.replace('P\?jaro', 'Pájaro')
df['tema'] = df['tema'].str.replace('cipr\?s', 'ciprés')
df['tema'] = df['tema'].str.replace('se\?or', 'señor')
df['tema'] = df['tema'].str.replace('mu\?eco', 'muñeco')
df['tema'] = df['tema'].str.replace('Sinton\?a', 'Sintonía')
df['tema'] = df['tema'].str.replace('bodeg\?n', 'bodegón')
df['tema'] = df['tema'].str.replace('Tentaci\?n', 'Tentación')
df['tema'] = df['tema'].str.replace('Celebraci\?n', 'Celebración')
df['tema'] = df['tema'].str.replace('\?ltimo', 'Último')
df['tema'] = df['tema'].str.replace('Lugare\?os', 'Lugareños')
df['tema'] = df['tema'].str.replace('F\?tbol', 'Fútbol')
df['tema'] = df['tema'].str.replace('\?ltimo', 'Último')
df['tema'] = df['tema'].str.replace('extra\?o', 'extraño')
df['tema'] = df['tema'].str.replace('Caf\? nueva', 'Café nueva')
df['tema'] = df['tema'].str.replace('Versi\?n', 'Versión')
df['tema'] = df['tema'].str.replace('rev\?s', 'revés')
df['tema'] = df['tema'].str.replace('Se\?or', 'Señor')
df['tema'] = df['tema'].str.replace('Caf\? de promesa', 'Café de promesa')
df['tema'] = df['tema'].str.replace('\?ltimo piel', 'Último piel')
df['tema'] = df['tema'].str.replace('D\?a boina', 'Día boina')
df['tema'] = df['tema'].str.replace('cig\?e\?a', 'cigüeña')
df['tema'] = df['tema'].str.replace('Claveles y cig\?e\?a', 'Claveles y cigüeña')
df['tema'] = df['tema'].str.replace('Tentaci\?n o silencio', 'Tentación o silencio')
df['tema'] = df['tema'].str.replace('Piedras p\?jaro', 'Piedras pájaro')
df['tema'] = df['tema'].str.replace('Respirar o sauces \(ac\?stico\)', 'Respirar o sauces (acústico)')
df['tema'] = df['tema'].str.replace('Qui\?n cestero', 'Quién cestero')
df['tema'] = df['tema'].str.replace('Alas o \?ltimo', 'Alas o último')
df['tema'] = df['tema'].str.replace('Discusion y caser\?o', 'Discusión y caserío')
df['tema'] = df['tema'].str.replace('Mec\?nico', 'Mecánico')
df['tema'] = df['tema'].str.replace('Sue\?o', 'Sueño')
df['tema'] = df['tema'].str.replace('discusi\?n', 'discusión')
df['tema'] = df['tema'].str.replace('caser\?o', 'caserío')
df['tema'] = df['tema'].str.replace('Perd\?n', 'Perdón')
df['tema'] = df['tema'].str.replace('rel\?mpago', 'relámpago')
df['tema'] = df['tema'].str.replace('Operaci\?n', 'Operación')
df['tema'] = df['tema'].str.replace('Loco o cig\?e?a', 'Loco o cigüeña')
df['tema'] = df['tema'].str.replace('Sue\?o pollo', 'Sueño pollo')
df['tema'] = df['tema'].str.replace('Venus de permanente \(ac\?stico\)', 'Venus de permanente (acústico)')
df['tema'] = df['tema'].str.replace('Adi\?s o coyote', 'Adiós o coyote')
df['tema'] = df['tema'].str.replace('Mec\?nico y recuerdos', 'Mecánico y recuerdos')
df['tema'] = df['tema'].str.replace('Lejan?a y amapolas', 'Lejanía y amapolas')
df['tema'] = df['tema'].str.replace('Cazador de adi?s', 'Cazador de adiós')
df['tema'] = df['tema'].str.replace('Equivocado de caser?o', 'Equivocado de caserío')
df['tema'] = df['tema'].str.replace('Mezcla o qui\?n', 'Mezcla o quién')
df['tema'] = df['tema'].str.replace('Adi\?s y ermitas', 'Adiós y ermitas')
df['tema'] = df['tema'].str.replace('Tequila perd?n', 'Tequila perdón')
df['tema'] = df['tema'].str.replace('Plut\?n y senda', 'Plutón y senda')
df['tema'] = df['tema'].str.replace('Justicia o adi\?s', 'Justicia o adiós')
df['tema'] = df['tema'].str.replace('arbol   y popurr\?', 'arbol y popurrí')
df['tema'] = df['tema'].str.replace('Verdad o due\?a', 'Verdad o dueña')
df['tema'] = df['tema'].str.replace('bodeg\?n', 'bodegón')
df['tema'] = df['tema'].str.replace('sinton\?a', 'sintonía')
df['tema'] = df['tema'].str.replace('ficci\?n', 'ficción')
df['tema'] = df['tema'].str.replace('Mec\?nico', 'Mecánico')
df['tema'] = df['tema'].str.replace('\?ltimo', 'Último')
df['tema'] = df['tema'].str.replace('Adi\?s', 'Adiós')
df['tema'] = df['tema'].str.replace('Ma\?ana', 'Mañana')
df['tema'] = df['tema'].str.replace('fantas\?a', 'fantasma')
df['tema'] = df['tema'].str.replace('operaci\?n', 'operación')
df['tema'] = df['tema'].str.replace('so\?ador', 'soñador')
df['tema'] = df['tema'].str.replace('Caf\?', 'Café')
df['tema'] = df['tema'].str.replace('estaci\?n', 'estación')
df['tema'] = df['tema'].str.replace('monta\?as', 'montañas')
df['tema'] = df['tema'].str.replace('discusi\?n', 'discusión')
df['tema'] = df['tema'].str.replace('H\?roe', 'Héroe')
df['tema'] = df['tema'].str.replace('Se\?or', 'Señor')
df['tema'] = df['tema'].str.replace('ac\?stico', 'acústico')
df['tema'] = df['tema'].str.replace('Bodeg\?n', 'Bodegón')
df['tema'] = df['tema'].str.replace('perd\?n', 'perdón')
df['tema'] = df['tema'].str.replace('Para\?so', 'Paraíso')
df['tema'] = df['tema'].str.replace('T\?nel', 'Túnel')
df['tema'] = df['tema'].str.replace('f\?tbol', 'fútbol')
df['tema'] = df['tema'].str.replace('Lejan\?a', 'Lejanía')
df['tema'] = df['tema'].str.replace('Coraz\?n', 'Corazón')
df['tema'] = df['tema'].str.replace('sue\?o', 'sueño')
df['tema'] = df['tema'].str.replace('Le\?ador', 'Leñador')
df['tema'] = df['tema'].str.replace('Mu\?eco', 'Muñeco')
df['tema'] = df['tema'].str.replace('Duende y popurr\?', 'Duende y popurrí')
df['tema'] = df['tema'].str.replace('D\?a o balada', 'Día o balada')
df['tema'] = df['tema'].str.replace('j\?piter', 'júpiter')
df['tema'] = df['tema'].str.replace('D\?a y orden', 'Día y orden')
df['tema'] = df['tema'].str.replace('Fantas\?a', 'Fantasía')
df['tema'] = df['tema'].str.replace('adi\?s', 'adiós')
df['tema'] = df['tema'].str.replace('Tequila perd\?n', 'Tequila perdón')
df['tema'] = df['tema'].str.replace('T\?nel o necesidad', 'Túnel o necesidad')
df['tema'] = df['tema'].str.replace('Extra\?o', 'Extraño')
df['tema'] = df['tema'].str.replace('T\?nel de qui\?n', 'Túnel de quién')
df['tema'] = df['tema'].str.replace('Ficci\?n', 'Ficción')
df['tema'] = df['tema'].str.replace('Plut\?n', 'Plutón')
df['tema'] = df['tema'].str.replace('Bodeg\?n', 'Bodegón')
df['tema'] = df['tema'].str.replace('adi\?s', 'adiós')
df['tema'] = df['tema'].str.replace('lejan\?a', 'lejanía')
df['tema'] = df['tema'].str.replace('p\?jaro', 'pájaro')
df['tema'] = df['tema'].str.replace('Mu\?eco', 'Muñeco')
df['tema'] = df['tema'].str.replace('Sult\?n', 'Sultán')
df['tema'] = df['tema'].str.replace('Ficci\?n', 'Ficción')
df['tema'] = df['tema'].str.replace('Sensaci\?n', 'Sensación')
df['tema'] = df['tema'].str.replace('Coraz\?n', 'Corazón')
df['tema'] = df['tema'].str.replace('lejan?a', 'lejanía')
df['tema'] = df['tema'].str.replace('lejan?a', 'lejanía')
df['tema'] = df['tema'].str.replace('p\?jaro', 'pájaro')
df['tema'] = df['tema'].str.replace('Mu\?eco', 'Muñeco')
df['tema'] = df['tema'].str.replace('Sult\?n', 'Sultán')
df['tema'] = df['tema'].str.replace('caf\?', 'café')
df['tema'] = df['tema'].str.replace('Gallinas adi\?s', 'Gallinas adiós')
df['tema'] = df['tema'].str.replace('Hombre despu\?s', 'Hombre después')
df['tema'] = df['tema'].str.replace('popurr\?', 'popurrí')
df['tema'] = df['tema'].str.replace('D\?a', 'Día')
df['tema'] = df['tema'].str.replace('sult\?n', 'sultán')
df['tema'] = df['tema'].str.replace('Ed\?n', 'Edén')
df['tema'] = df['tema'].str.replace('Hombre despu?s', 'Hombre después')
df['tema'] = df['tema'].str.replace('qui\?n ', 'quién')
df['tema'] = df['tema'].str.replace('despu\?s', 'después')
df['tema'] = df['tema'].str.replace('Túnel de qui\?n', 'Túnel de quien')
df['tema'] = df['tema'].str.replace('Cig\?e', 'Cigüe')
df['tema'] = df['tema'].str.replace('qui\?n', 'quién')
df['tema'] = df['tema'].str.replace('ni\?os', 'niños')
df['tema'] = df['tema'].str.replace('Mec\?nica', 'Mecánica')
df['tema'] = df['tema'].str.replace('Berl\?n', 'Berlín')
df['tema'] = df['tema'].str.replace('\?frica', 'África')
df['tema'] = df['tema'].str.replace('due\?a', 'dueña')
df['tema'] = df['tema'].str.replace('Qui\?n', 'Quién')
df['tema'] = df['tema'].str.replace('\?a', 'ña')
df['tema'] = df['tema'].str.replace('Par\?s', 'París')
df['tema'] = df['tema'].str.replace('Mosc\?', 'Moscú')
df['tema'] = df['tema'].str.replace('autob\?s', 'autobús')

df['autor'] = df['autor'].str.replace('Virgi\?o', 'Virgilio')
df['autor'] = df['autor'].str.replace('Carli\?a', 'Carlia')
df['autor'] = df['autor'].str.replace('Due\?as', 'Dueñas')
df['autor'] = df['autor'].str.replace('Mu\?oz', 'Muñoz')
df['autor'] = df['autor'].str.replace('Noeli\?a', 'Noelia')
df['autor'] = df['autor'].str.replace('\?lvarez', 'Álvarez')
df['autor'] = df['autor'].str.replace('Cloti\?a', 'Clotia')
df['autor'] = df['autor'].str.replace('Agusti\?o', 'Agustín')
df['autor'] = df['autor'].str.replace('de la Luna Mu\?iz', 'de la Luna Muñiz')
df['autor'] = df['autor'].str.replace('de los \?ngeles Mu\?oz', 'de los Ángeles Muñoz')
df['autor'] = df['autor'].str.replace('Ordo\?ez', 'Ordoñez')
df['autor'] = df['autor'].str.replace('Daniel Pa\?ez', 'Daniel Páez')
df['autor'] = df['autor'].str.replace('E.C.\?', 'E.C.Ñ.')
df['autor'] = df['autor'].str.replace('Ovidi\?a', 'Ovidia')
df['autor'] = df['autor'].str.replace('Azucena Nu\?ez', 'Azucena Nuñez')
df['autor'] = df['autor'].str.replace('Clori\?a', 'Cloria')
df['autor'] = df['autor'].str.replace('Dani\?o', 'Danio')
df['autor'] = df['autor'].str.replace('Patri\?a', 'Patria')
df['autor'] = df['autor'].str.replace('Staples \?avincopa', 'Staples Navincopa')
df['autor'] = df['autor'].str.replace('Domi\?o', 'Dominio')
df['autor'] = df['autor'].str.replace('Maria de los \?ngeles Muñoz', 'Maria de los Ángeles Muñoz')
df['autor'] = df['autor'].str.replace('Ag\?ero', 'Agüero')
df['autor'] = df['autor'].str.replace('Mauri\?a', 'Mauricia')
df['autor'] = df['autor'].str.replace('Bauti\?o', 'Bautiño')
df['autor'] = df['autor'].str.replace('\?anez', 'Cáñez')
df['autor'] = df['autor'].str.replace('\?ngeles', 'Ángeles')
df['autor'] = df['autor'].str.replace('Verdi\?a', 'Verdía')
df['autor'] = df['autor'].str.replace('Yuri\?o', 'Yuriño')
df['autor'] = df['autor'].str.replace('Dari\?o', 'Darío')
df['autor'] = df['autor'].str.replace('Mu\?ante', 'Muñante')
df['autor'] = df['autor'].str.replace('\?vila', 'Ávila')
df['autor'] = df['autor'].str.replace('Prisci\?a', 'Priscila')
df['autor'] = df['autor'].str.replace('Rodri\?o', 'Rodrigo')
df['autor'] = df['autor'].str.replace('Placi\?o', 'Placio')
df['autor'] = df['autor'].str.replace('Berti\?a', 'Bertiza')
df['autor'] = df['autor'].str.replace('P.P.\?.', 'P.P.A.')
df['autor'] = df['autor'].str.replace('Elvi\?a', 'Elvia')
df['autor'] = df['autor'].str.replace('Mari\?o', 'Mariño')

df['gira'] = df['gira'].str.replace('discusi\?n', 'discusión')
df['gira'] = df['gira'].str.replace('adi\?s', 'adiós')
df['gira'] = df['gira'].str.replace('p\?jaro', 'pájaro')
df['gira'] = df['gira'].str.replace('Lugare\?os', 'Lugareños')
df['gira'] = df['gira'].str.replace('t\?nel', 'túnel')
df['gira'] = df['gira'].str.replace('Dari\?o', 'Darío')
df['gira'] = df['gira'].str.replace('\?vila', 'Ávila')
df['gira'] = df['gira'].str.replace('Regardotop\?a', 'Regardotopía')
df['gira'] = df['gira'].str.replace('caser\?o', 'caserío')
df['gira'] = df['gira'].str.replace('Ag\?ero', 'Agüero')
df['gira'] = df['gira'].str.replace('qui\?n', 'quién')
df['gira'] = df['gira'].str.replace('rel\?mpago', 'relámpago')
df['gira'] = df['gira'].str.replace('se\?ora', 'señora')
df['gira'] = df['gira'].str.replace('Par\?s', 'París')
df['gira'] = df['gira'].str.replace('para\?so', 'paraíso')
df['gira'] = df['gira'].str.replace('estaci\?n', 'estación')
df['gira'] = df['gira'].str.replace('M\?sica', 'Música')
df['gira'] = df['gira'].str.replace('Mu\?ante', 'Muñante')
df['gira'] = df['gira'].str.replace('due\?a', 'dueña')
df['gira'] = df['gira'].str.replace('monta\?as', 'montañas')
df['gira'] = df['gira'].str.replace('Due\?as', 'Dueñas')
df['gira'] = df['gira'].str.replace('extra\?o', 'extraño')
df['gira'] = df['gira'].str.replace('fantas\?a', 'fantasía')
df['gira'] = df['gira'].str.replace('\?ltimo', 'último')
df['gira'] = df['gira'].str.replace('P.P.\?.', 'P.P.A.')
df['gira'] = df['gira'].str.replace('Mu\?oz', 'Muñoz')
df['gira'] = df['gira'].str.replace('Mauri\?a', 'Mauricia')
df['gira'] = df['gira'].str.replace('j\?piter', 'Júpiter')
df['gira'] = df['gira'].str.replace('Verdi\?a', 'Verdía')
df['gira'] = df['gira'].str.replace('En\?logos', 'Enólogos')
df['gira'] = df['gira'].str.replace('se\?or', 'señor')
df['gira'] = df['gira'].str.replace('lejan\?a', 'lejanía')
df['gira'] = df['gira'].str.replace('Rodri\?o', 'Rodrigo')
df['gira'] = df['gira'].str.replace('popurr\?', 'popurrí')
df['gira'] = df['gira'].str.replace('celebraci\?n', 'celebración')
df['gira'] = df['gira'].str.replace('caf\?', 'café')

df['interprete'] = df['interprete'].str.replace('Due\?as', 'Dueñas')
df['interprete'] = df['interprete'].str.replace('Ag\?ero', 'Agüero')
df['interprete'] = df['interprete'].str.replace('Mauri\?a', 'Mauricia')
df['interprete'] = df['interprete'].str.replace('Lugare\?os', 'Lugareños')
df['interprete'] = df['interprete'].str.replace('P\?jaros', 'Pájaros')
df['interprete'] = df['interprete'].str.replace('Par\?s', 'París')
df['interprete'] = df['interprete'].str.replace('Verdi\?a', 'Verdía')
df['interprete'] = df['interprete'].str.replace('En\?logos', 'Enólogos')
df['interprete'] = df['interprete'].str.replace('Mu\?ante', 'Muñante')
df['interprete'] = df['interprete'].str.replace('\?vila', 'Ávila')
df['interprete'] = df['interprete'].str.replace('Dari\?o', 'Darío')
df['interprete'] = df['interprete'].str.replace('Rodri\?o', 'Rodrigo')
df['interprete'] = df['interprete'].str.replace('Regardotop\?a', 'Regardotopía')
df['interprete'] = df['interprete'].str.replace('P.P.\?.', 'P.P.A.')
df['interprete'] = df['interprete'].str.replace('Mu\?oz', 'Muñoz')

if file_number == 18: # csv conciertos_18: 4208731	'86 of devil through the turmoi	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN
    df.loc[4208731] = df.loc[4208730]
    df.loc[4208731]['orden'] = 12  # orden was 11 in previous row

df['duracion_total'] = df['duracion_total'].astype(int)
# df['orden'] = df['orden'].astype(int)
# df['duracion'] = df['duracion'].astype(int)
# Out:
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_4175/254178212.py:10: DtypeWarning: Columns (6,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', header=None, delimiter=",", names=column_names)
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_4175/254178212.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['COLUMN_12'] = df.query("not COLUMN_11.isnull()")['COLUMN_5'] + " " + df.query("not COLUMN_11.isnull()")['COLUMN_4'].str.replace('\\', '')
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_4175/254178212.py:26: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %%
# Look for malformed words in a column of the CSV
bad_names = df[df['orden'] == ("\\N")] # Change column names to check 1029412 -> 1029412	The '05 of youngster Tour	Wenceslao_	24/07/05	Mistvalley	Russian Federation	105	\N	\N	\N	\N	\N
print(bad_names.to_string())
# Out:
#                               gira  interprete     fecha                            lugar                                    pais  duracion_total orden tema pasaporte_autor autor duracion
# 1029412  The '05 of youngster Tour  Wenceslao_  24/07/05                       Mistvalley                      Russian Federation             105    \N   \N              \N    \N       \N
# 1034594             '10 earth Tour  Wenceslao_  28/08/10                         Soupside                             Saint Lucia             106    \N   \N              \N    \N       \N
# 1039997                        NaN  Wenceslao_  07/07/06                        Sunnytown                            Cook Islands             115    \N   \N              \N    \N       \N
# 1039998                        NaN  Wenceslao_  08/10/04                      Soupborough                Islamic Republic of Iran              85    \N   \N              \N    \N       \N
# ...

# %%
import re
p = re.compile('([\w\.]*\?[\w\.]*)')

words = [p.findall(s) for s in bad_names]

words = list(set([item for sublist in words for item in sublist]))
words
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/josedavidricodias/Desktop/Universidad/5º/Primer semestre/PRACITCA/cleaning.ipynb Celda 6 line 4
#       <a href='vscode-notebook-cell:/Users/josedavidricodias/Desktop/Universidad/5%C2%BA/Primer%20semestre/PRACITCA/cleaning.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> import re
#       <a href='vscode-notebook-cell:/Users/josedavidricodias/Desktop/Universidad/5%C2%BA/Primer%20semestre/PRACITCA/cleaning.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> p = re.compile('([\w\.]*\?[\w\.]*)')
# ----> <a href='vscode-notebook-cell:/Users/josedavidricodias/Desktop/Universidad/5%C2%BA/Primer%20semestre/PRACITCA/cleaning.ipynb#X42sZmlsZQ%3D%3D?line=3'>4</a> words = [p.findall(s) for s in bad_names]
# ...

# %%
# import re
# p = re.compile('([\w\.]*\?[\w\.]*)')

words = [p.findall(s) for s in bad_names]

words = list(set([item for sublist in words for item in sublist]))
words

# %%
# Generate the python code to copy-paste
res = []
corrected_words = ['París', 'Moscú', 'autobús'] # This comes from ChatGPT

for index, value in enumerate(words):
    print(value)
    res.append("df['tema'] = df['tema'].str.replace('"+str(value).replace('?', ""+'\\?')+"', '"+corrected_words[index]+"')")

for result in res:
    print(res)

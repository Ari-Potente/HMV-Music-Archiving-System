# %%
import pandas as pd
pd.set_option('display.max_rows', None)
from numpy import where

# %% [markdown]
# ### Loop the data lines
# for file_number in range(1, 23+1):
#     with open('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', 'r') as temp_f:
#         # get No of columns in each line
#         col_count = [ len(l.split(",")) for l in temp_f.readlines() ]
#
#     ### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
#     column_names = ['COLUMN_'+str(i) for i in range(0, max(col_count))]
#
#     ### Read csv
#     df = pd.read_csv('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', header=None, delimiter=",", names=column_names)
#
#     df = df.drop(0)
#
#     df['COLUMN_12'] = df.query("not COLUMN_11.isnull()")['COLUMN_5'] + " " + df.query("not COLUMN_11.isnull()")['COLUMN_4'].str.replace('\\', '')
#     df['COLUMN_12'] = df['COLUMN_12'].str.replace('_', '\'')
#     df['COLUMN_4'] = where(df['COLUMN_12'].isnull(), df['COLUMN_4'], df['COLUMN_12'])
#
#     df['COLUMN_5'] = where(df['COLUMN_12'].isnull(), df['COLUMN_5'], df['COLUMN_6'])
#     df['COLUMN_6'] = where(df['COLUMN_12'].isnull(), df['COLUMN_6'], df['COLUMN_7'])
#     df['COLUMN_7'] = where(df['COLUMN_12'].isnull(), df['COLUMN_7'], df['COLUMN_8'])
#     df['COLUMN_8'] = where(df['COLUMN_12'].isnull(), df['COLUMN_8'], df['COLUMN_9'])
#     df['COLUMN_9'] = where(df['COLUMN_12'].isnull(), df['COLUMN_9'], df['COLUMN_10'])
#     df['COLUMN_10'] = where(df['COLUMN_12'].isnull(), df['COLUMN_10'], df['COLUMN_11'])
#     df.drop(columns=['COLUMN_11', 'COLUMN_12'], inplace=True)
#
#     df = df.rename(columns={'COLUMN_0': 'gira','COLUMN_1': 'interprete_o_banda', 'COLUMN_2': 'fecha', 'COLUMN_3': 'lugar', 'COLUMN_4': 'pais', 'COLUMN_5': 'duracion_total', 'COLUMN_6': 'orden', 'COLUMN_7': 'titulo', 'COLUMN_8': 'pasaporte_autor', 'COLUMN_9': 'autor', 'COLUMN_10': 'duracion'})
#
#     df.to_csv('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'_filtered.csv')

# %%
### Read csv
df = pd.read_csv('/Users/josedavidricodias/Downloads/Music_dumps/temas.csv', delimiter=",")


df['autor'] = df['autor'].str.replace('Virgi\?o', 'Virgilio')
df['autor'] = df['autor'].str.replace('Carli\?a', 'Carlia')
df['autor'] = df['autor'].str.replace('Due\?as', 'Dueñas')
df['autor'] = df['autor'].str.replace('Mu\?oz', 'Muñoz')
df['autor'] = df['autor'].str.replace('Noeli\?a', 'Noelia')
df['autor'] = df['autor'].str.replace('\?lvarez', 'Álvarez')
df['autor'] = df['autor'].str.replace('Cloti\?a', 'Clotia')
df['autor'] = df['autor'].str.replace('Agusti\?o', 'Agustín')
df['autor'] = df['autor'].str.replace('de la Luna Mu\?iz', 'de la Luna Muñiz')
df['autor'] = df['autor'].str.replace('de los \?ngeles Mu\?oz', 'de los Ángeles Muñoz')
df['autor'] = df['autor'].str.replace('Ordo\?ez', 'Ordoñez')
df['autor'] = df['autor'].str.replace('Daniel Pa\?ez', 'Daniel Páez')
df['autor'] = df['autor'].str.replace('E.C.\?', 'E.C.Ñ.')
df['autor'] = df['autor'].str.replace('Ovidi\?a', 'Ovidia')
df['autor'] = df['autor'].str.replace('Azucena Nu\?ez', 'Azucena Nuñez')
df['autor'] = df['autor'].str.replace('Clori\?a', 'Cloria')
df['autor'] = df['autor'].str.replace('Dani\?o', 'Danio')
df['autor'] = df['autor'].str.replace('Patri\?a', 'Patria')
df['autor'] = df['autor'].str.replace('Staples \?avincopa', 'Staples Navincopa')
df['autor'] = df['autor'].str.replace('Domi\?o', 'Dominio')
df['autor'] = df['autor'].str.replace('Maria de los \?ngeles Muñoz', 'Maria de los Ángeles Muñoz')
df['autor'] = df['autor'].str.replace('Ag\?ero', 'Agüero')
df['autor'] = df['autor'].str.replace('Mauri\?a', 'Mauricia')
df['autor'] = df['autor'].str.replace('Bauti\?o', 'Bautiño')
df['autor'] = df['autor'].str.replace('\?anez', 'Cáñez')
df['autor'] = df['autor'].str.replace('\?ngeles', 'Ángeles')
df['autor'] = df['autor'].str.replace('Verdi\?a', 'Verdía')
df['autor'] = df['autor'].str.replace('Yuri\?o', 'Yuriño')
df['autor'] = df['autor'].str.replace('Dari\?o', 'Darío')
df['autor'] = df['autor'].str.replace('Mu\?ante', 'Muñante')
df['autor'] = df['autor'].str.replace('\?vila', 'Ávila')
df['autor'] = df['autor'].str.replace('Prisci\?a', 'Priscila')
df['autor'] = df['autor'].str.replace('Rodri\?o', 'Rodrigo')
df['autor'] = df['autor'].str.replace('Placi\?o', 'Placio')
df['autor'] = df['autor'].str.replace('Berti\?a', 'Bertiza')
df['autor'] = df['autor'].str.replace('P.P.\?.', 'P.P.A.')
df['autor'] = df['autor'].str.replace('Elvi\?a', 'Elvia')
df['autor'] = df['autor'].str.replace('Mari\?o', 'Mariño')
df['autor'] = df['autor'].str.replace('Barri\?o', 'Barrito')
df['autor'] = df['autor'].str.replace('Paci\?a', 'Matiño')
df['autor'] = df['autor'].str.replace('Alci\?o', 'Maxia')
df['autor'] = df['autor'].str.replace('Barri\?o', 'Pacía')
df['autor'] = df['autor'].str.replace('Fabi\?o', 'Abrío')
df['autor'] = df['autor'].str.replace('Mati\?o', 'Ocampo Ocaña')
df['autor'] = df['autor'].str.replace('Maxi\?a', 'Raúl Páez')
df['autor'] = df['autor'].str.replace('Abri\?o', 'Obdulia Muñayco')
df['autor'] = df['autor'].str.replace('Oca\?a', 'Alciño')
df['autor'] = df['autor'].str.replace('Betti\?a', 'Barriño')
df['autor'] = df['autor'].str.replace('Pa\?ez', 'Fabiño')
df['autor'] = df['autor'].str.replace('Mu\?ayco', 'Bettía')

df['titulo'] = df['titulo'].str.replace('Tourn\?e', 'Tournée')
df['titulo'] = df['titulo'].str.replace('lugare\?os', 'lugareños')
df['titulo'] = df['titulo'].str.replace('ed\?n', 'edén')
df['titulo'] = df['titulo'].str.replace('Carli\?a', 'Carliña')
df['titulo'] = df['titulo'].str.replace('cipr\?s', 'ciprés')
df['titulo'] = df['titulo'].str.replace('sensaci\?n', 'sensación')
df['titulo'] = df['titulo'].str.replace('plut\?n', 'plutón')
df['titulo'] = df['titulo'].str.replace('le\?ador', 'leñador')
df['titulo'] = df['titulo'].str.replace('mec\?nico', 'mecánico')
df['titulo'] = df['titulo'].str.replace('tentaci\?n', 'tentación')
df['titulo'] = df['titulo'].str.replace('az\?car', 'azúcar')
df['titulo'] = df['titulo'].str.replace('mec\?nic', 'mecánic')
df['titulo'] = df['titulo'].str.replace('c\?mo', 'cómo')
df['titulo'] = df['titulo'].str.replace('sinton\?a', 'sintonía')
df['titulo'] = df['titulo'].str.replace('versi\?n', 'versión')
df['titulo'] = df['titulo'].str.replace('d\?a', 'día')
df['titulo'] = df['titulo'].str.replace('h\?roe', 'héroe')
df['titulo'] = df['titulo'].str.replace('melod\?a', 'melodía')
df['titulo'] = df['titulo'].str.replace('televisi\?n', 'televisión')
df['titulo'] = df['titulo'].str.replace('coraz\?n', 'corazón')
df['titulo'] = df['titulo'].str.replace('ma\?ana', 'mañana')
df['titulo'] = df['titulo'].str.replace('Clori\?a', 'Cloriña')
df['titulo'] = df['titulo'].str.replace('antesdespu\?s', 'antesdespués')
df['titulo'] = df['titulo'].str.replace('\?xito', 'éxito')
df['titulo'] = df['titulo'].str.replace('Ma\?anitas', 'Mañanitas')
df['titulo'] = df['titulo'].str.replace('Pa\?ez', 'Pañez')
df['titulo'] = df['titulo'].str.replace('Domi\?o', 'Domiño')
df['titulo'] = df['titulo'].str.replace('\?avincopa', 'Ñavincopa')
df['titulo'] = df['titulo'].str.replace('sue\?os', 'sueños')
df['titulo'] = df['titulo'].str.replace('Dani\?o', 'Daniño')
df['titulo'] = df['titulo'].str.replace('Cig\?e\?ales', 'Cigüeñales')
df['titulo'] = df['titulo'].str.replace('Carli\?a', 'Carliña')
df['titulo'] = df['titulo'].str.replace('Clori\?a', 'Cloriña')
df['titulo'] = df['titulo'].str.replace('Pa\?ez', 'Pañez')
df['titulo'] = df['titulo'].str.replace('Dani\?o', 'Daniño')
df['titulo'] = df['titulo'].str.replace('Ma\?anitas', 'Mañanitas')
df['titulo'] = df['titulo'].str.replace('Domi\?o', 'Domiño')
df['titulo'] = df['titulo'].str.replace('Cal\?', 'Calí')
df['titulo'] = df['titulo'].str.replace('\?avincopa', 'Ñavincopa')
df['titulo'] = df['titulo'].str.replace('Cig\?e\?ales', 'Cigüeñales')
df['titulo'] = df['titulo'].str.replace('Rev\?s', 'Revés')
df['titulo'] = df['titulo'].str.replace('Televisi\?n', 'Televisión')
df['titulo'] = df['titulo'].str.replace('\?rbol', 'árbol')
df['titulo'] = df['titulo'].str.replace('para\?so', 'paraíso')
df['titulo'] = df['titulo'].str.replace('J\?piter', 'Júpiter')
df['titulo'] = df['titulo'].str.replace('So\?ador', 'Soñador')
df['titulo'] = df['titulo'].str.replace('se\?ora', 'señora')
df['titulo'] = df['titulo'].str.replace('le\?ador', 'leñador')
df['titulo'] = df['titulo'].str.replace('sensaci\?n', 'sensación')
df['titulo'] = df['titulo'].str.replace('mec\?nica', 'mecánica')
df['titulo'] = df['titulo'].str.replace('Discusi\?n', 'Discusión')
df['titulo'] = df['titulo'].str.replace('Melod\?a', 'Melodía')
df['titulo'] = df['titulo'].str.replace('t\?nel', 'túnel')
df['titulo'] = df['titulo'].str.replace('Az\?car', 'Azúcar')
df['titulo'] = df['titulo'].str.replace('Monta\?as', 'Montañas')
df['titulo'] = df['titulo'].str.replace('\?rbol', 'árbol')
df['titulo'] = df['titulo'].str.replace('celebraci\?n', 'celebración')
df['titulo'] = df['titulo'].str.replace('coraz\?n', 'corazón')
df['titulo'] = df['titulo'].str.replace('cipr\?s', 'ciprés')
df['titulo'] = df['titulo'].str.replace('Melod\?a de versi\?n', 'Melodía de versión')
df['titulo'] = df['titulo'].str.replace('h\?roe', 'héroe')
df['titulo'] = df['titulo'].str.replace('Rel\?mpago', 'Relámpago')
df['titulo'] = df['titulo'].str.replace('J\?piter', 'Júpiter')
df['titulo'] = df['titulo'].str.replace('c\?mo', 'cómo')
df['titulo'] = df['titulo'].str.replace('televisi\?n', 'televisión')
df['titulo'] = df['titulo'].str.replace('Due\?a', 'Dueña')
df['titulo'] = df['titulo'].str.replace('Popurr\?', 'Popurrí')
df['titulo'] = df['titulo'].str.replace('m\?sica', 'música')
df['titulo'] = df['titulo'].str.replace('C\?mo', 'Cómo')
df['titulo'] = df['titulo'].str.replace('Estaci\?n', 'Estación')
df['titulo'] = df['titulo'].str.replace('Cipr\?s', 'Ciprés')
df['titulo'] = df['titulo'].str.replace('televisi\?n', 'televisión')
df['titulo'] = df['titulo'].str.replace('P\?jaro', 'Pájaro')
df['titulo'] = df['titulo'].str.replace('m\?sica', 'música')
df['titulo'] = df['titulo'].str.replace('M\?sica', 'Música')
df['titulo'] = df['titulo'].str.replace('ed\?n', 'edén')
df['titulo'] = df['titulo'].str.replace('J\?piter', 'Júpiter')
df['titulo'] = df['titulo'].str.replace('le\?ador', 'leñador')
df['titulo'] = df['titulo'].str.replace('lugare\?os', 'lugareños')
df['titulo'] = df['titulo'].str.replace('Caser\?o', 'Caserío')
df['titulo'] = df['titulo'].str.replace('h\?roe', 'héroe')
df['titulo'] = df['titulo'].str.replace('c\?mo', 'cómo')
df['titulo'] = df['titulo'].str.replace('Melod\?a', 'Melodía')
df['titulo'] = df['titulo'].str.replace('coraz\?n', 'corazón')
df['titulo'] = df['titulo'].str.replace('Az\?car', 'Azúcar')
df['titulo'] = df['titulo'].str.replace('Ni\?os', 'Niños')
df['titulo'] = df['titulo'].str.replace('P\?jaro', 'Pájaro')
df['titulo'] = df['titulo'].str.replace('cipr\?s', 'ciprés')
df['titulo'] = df['titulo'].str.replace('se\?or', 'señor')
df['titulo'] = df['titulo'].str.replace('mu\?eco', 'muñeco')
df['titulo'] = df['titulo'].str.replace('Sinton\?a', 'Sintonía')
df['titulo'] = df['titulo'].str.replace('bodeg\?n', 'bodegón')
df['titulo'] = df['titulo'].str.replace('Tentaci\?n', 'Tentación')
df['titulo'] = df['titulo'].str.replace('Celebraci\?n', 'Celebración')
df['titulo'] = df['titulo'].str.replace('\?ltimo', 'Último')
df['titulo'] = df['titulo'].str.replace('Lugare\?os', 'Lugareños')
df['titulo'] = df['titulo'].str.replace('F\?tbol', 'Fútbol')
df['titulo'] = df['titulo'].str.replace('\?ltimo', 'Último')
df['titulo'] = df['titulo'].str.replace('extra\?o', 'extraño')
df['titulo'] = df['titulo'].str.replace('Caf\? nueva', 'Café nueva')
df['titulo'] = df['titulo'].str.replace('Versi\?n', 'Versión')
df['titulo'] = df['titulo'].str.replace('rev\?s', 'revés')
df['titulo'] = df['titulo'].str.replace('Se\?or', 'Señor')
df['titulo'] = df['titulo'].str.replace('Caf\? de promesa', 'Café de promesa')
df['titulo'] = df['titulo'].str.replace('\?ltimo piel', 'Último piel')
df['titulo'] = df['titulo'].str.replace('D\?a boina', 'Día boina')
df['titulo'] = df['titulo'].str.replace('cig\?e\?a', 'cigüeña')
df['titulo'] = df['titulo'].str.replace('Claveles y cig\?e\?a', 'Claveles y cigüeña')
df['titulo'] = df['titulo'].str.replace('Tentaci\?n o silencio', 'Tentación o silencio')
df['titulo'] = df['titulo'].str.replace('Piedras p\?jaro', 'Piedras pájaro')
df['titulo'] = df['titulo'].str.replace('Respirar o sauces \(ac\?stico\)', 'Respirar o sauces (acústico)')
df['titulo'] = df['titulo'].str.replace('Qui\?n cestero', 'Quién cestero')
df['titulo'] = df['titulo'].str.replace('Alas o \?ltimo', 'Alas o último')
df['titulo'] = df['titulo'].str.replace('Discusion y caser\?o', 'Discusión y caserío')
df['titulo'] = df['titulo'].str.replace('Mec\?nico', 'Mecánico')
df['titulo'] = df['titulo'].str.replace('Sue\?o', 'Sueño')
df['titulo'] = df['titulo'].str.replace('discusi\?n', 'discusión')
df['titulo'] = df['titulo'].str.replace('caser\?o', 'caserío')
df['titulo'] = df['titulo'].str.replace('Perd\?n', 'Perdón')
df['titulo'] = df['titulo'].str.replace('rel\?mpago', 'relámpago')
df['titulo'] = df['titulo'].str.replace('Operaci\?n', 'Operación')
df['titulo'] = df['titulo'].str.replace('Loco o cig\?e?a', 'Loco o cigüeña')
df['titulo'] = df['titulo'].str.replace('Sue\?o pollo', 'Sueño pollo')
df['titulo'] = df['titulo'].str.replace('Venus de permanente \(ac\?stico\)', 'Venus de permanente (acústico)')
df['titulo'] = df['titulo'].str.replace('Adi\?s o coyote', 'Adiós o coyote')
df['titulo'] = df['titulo'].str.replace('Mec\?nico y recuerdos', 'Mecánico y recuerdos')
df['titulo'] = df['titulo'].str.replace('Lejan?a y amapolas', 'Lejanía y amapolas')
df['titulo'] = df['titulo'].str.replace('Cazador de adi?s', 'Cazador de adiós')
df['titulo'] = df['titulo'].str.replace('Equivocado de caser?o', 'Equivocado de caserío')
df['titulo'] = df['titulo'].str.replace('Mezcla o qui\?n', 'Mezcla o quién')
df['titulo'] = df['titulo'].str.replace('Adi\?s y ermitas', 'Adiós y ermitas')
df['titulo'] = df['titulo'].str.replace('Tequila perd?n', 'Tequila perdón')
df['titulo'] = df['titulo'].str.replace('Plut\?n y senda', 'Plutón y senda')
df['titulo'] = df['titulo'].str.replace('Justicia o adi\?s', 'Justicia o adiós')
df['titulo'] = df['titulo'].str.replace('arbol   y popurr\?', 'arbol y popurrí')
df['titulo'] = df['titulo'].str.replace('Verdad o due\?a', 'Verdad o dueña')
df['titulo'] = df['titulo'].str.replace('bodeg\?n', 'bodegón')
df['titulo'] = df['titulo'].str.replace('sinton\?a', 'sintonía')
df['titulo'] = df['titulo'].str.replace('ficci\?n', 'ficción')
df['titulo'] = df['titulo'].str.replace('Mec\?nico', 'Mecánico')
df['titulo'] = df['titulo'].str.replace('\?ltimo', 'Último')
df['titulo'] = df['titulo'].str.replace('Adi\?s', 'Adiós')
df['titulo'] = df['titulo'].str.replace('Ma\?ana', 'Mañana')
df['titulo'] = df['titulo'].str.replace('fantas\?a', 'fantasma')
df['titulo'] = df['titulo'].str.replace('operaci\?n', 'operación')
df['titulo'] = df['titulo'].str.replace('so\?ador', 'soñador')
df['titulo'] = df['titulo'].str.replace('Caf\?', 'Café')
df['titulo'] = df['titulo'].str.replace('estaci\?n', 'estación')
df['titulo'] = df['titulo'].str.replace('monta\?as', 'montañas')
df['titulo'] = df['titulo'].str.replace('discusi\?n', 'discusión')
df['titulo'] = df['titulo'].str.replace('H\?roe', 'Héroe')
df['titulo'] = df['titulo'].str.replace('Se\?or', 'Señor')
df['titulo'] = df['titulo'].str.replace('ac\?stico', 'acústico')
df['titulo'] = df['titulo'].str.replace('Bodeg\?n', 'Bodegón')
df['titulo'] = df['titulo'].str.replace('perd\?n', 'perdón')
df['titulo'] = df['titulo'].str.replace('Para\?so', 'Paraíso')
df['titulo'] = df['titulo'].str.replace('T\?nel', 'Túnel')
df['titulo'] = df['titulo'].str.replace('f\?tbol', 'fútbol')
df['titulo'] = df['titulo'].str.replace('Lejan\?a', 'Lejanía')
df['titulo'] = df['titulo'].str.replace('Coraz\?n', 'Corazón')
df['titulo'] = df['titulo'].str.replace('sue\?o', 'sueño')
df['titulo'] = df['titulo'].str.replace('Le\?ador', 'Leñador')
df['titulo'] = df['titulo'].str.replace('Mu\?eco', 'Muñeco')
df['titulo'] = df['titulo'].str.replace('Duende y popurr\?', 'Duende y popurrí')
df['titulo'] = df['titulo'].str.replace('D\?a o balada', 'Día o balada')
df['titulo'] = df['titulo'].str.replace('j\?piter', 'júpiter')
df['titulo'] = df['titulo'].str.replace('D\?a y orden', 'Día y orden')
df['titulo'] = df['titulo'].str.replace('Fantas\?a', 'Fantasía')
df['titulo'] = df['titulo'].str.replace('adi\?s', 'adiós')
df['titulo'] = df['titulo'].str.replace('Tequila perd\?n', 'Tequila perdón')
df['titulo'] = df['titulo'].str.replace('T\?nel o necesidad', 'Túnel o necesidad')
df['titulo'] = df['titulo'].str.replace('Extra\?o', 'Extraño')
df['titulo'] = df['titulo'].str.replace('T\?nel de qui\?n', 'Túnel de quién')
df['titulo'] = df['titulo'].str.replace('Ficci\?n', 'Ficción')
df['titulo'] = df['titulo'].str.replace('Plut\?n', 'Plutón')
df['titulo'] = df['titulo'].str.replace('Bodeg\?n', 'Bodegón')
df['titulo'] = df['titulo'].str.replace('adi\?s', 'adiós')
df['titulo'] = df['titulo'].str.replace('lejan\?a', 'lejanía')
df['titulo'] = df['titulo'].str.replace('p\?jaro', 'pájaro')
df['titulo'] = df['titulo'].str.replace('Mu\?eco', 'Muñeco')
df['titulo'] = df['titulo'].str.replace('Sult\?n', 'Sultán')
df['titulo'] = df['titulo'].str.replace('Ficci\?n', 'Ficción')
df['titulo'] = df['titulo'].str.replace('Sensaci\?n', 'Sensación')
df['titulo'] = df['titulo'].str.replace('Coraz\?n', 'Corazón')
df['titulo'] = df['titulo'].str.replace('lejan?a', 'lejanía')
df['titulo'] = df['titulo'].str.replace('lejan?a', 'lejanía')
df['titulo'] = df['titulo'].str.replace('p\?jaro', 'pájaro')
df['titulo'] = df['titulo'].str.replace('Mu\?eco', 'Muñeco')
df['titulo'] = df['titulo'].str.replace('Sult\?n', 'Sultán')
df['titulo'] = df['titulo'].str.replace('caf\?', 'café')
df['titulo'] = df['titulo'].str.replace('Gallinas adi\?s', 'Gallinas adiós')
df['titulo'] = df['titulo'].str.replace('Hombre despu\?s', 'Hombre después')
df['titulo'] = df['titulo'].str.replace('popurr\?', 'popurrí')
df['titulo'] = df['titulo'].str.replace('D\?a', 'Día')
df['titulo'] = df['titulo'].str.replace('sult\?n', 'sultán')
df['titulo'] = df['titulo'].str.replace('Ed\?n', 'Edén')
df['titulo'] = df['titulo'].str.replace('Hombre despu?s', 'Hombre después')
df['titulo'] = df['titulo'].str.replace('qui\?n ', 'quién')
df['titulo'] = df['titulo'].str.replace('despu\?s', 'después')
df['titulo'] = df['titulo'].str.replace('Túnel de qui\?n', 'Túnel de quien')
df['titulo'] = df['titulo'].str.replace('Cig\?e', 'Cigüe')
df['titulo'] = df['titulo'].str.replace('qui\?n', 'quién')
df['titulo'] = df['titulo'].str.replace('ni\?os', 'niños')
df['titulo'] = df['titulo'].str.replace('Mec\?nica', 'Mecánica')
df['titulo'] = df['titulo'].str.replace('Berl\?n', 'Berlín')
df['titulo'] = df['titulo'].str.replace('\?frica', 'África')
df['titulo'] = df['titulo'].str.replace('due\?a', 'dueña')
df['titulo'] = df['titulo'].str.replace('Qui\?n', 'Quién')
df['titulo'] = df['titulo'].str.replace('\?a', 'ña')
df['titulo'] = df['titulo'].str.replace('Par\?s', 'París')
df['titulo'] = df['titulo'].str.replace('Mosc\?', 'Moscú')
df['titulo'] = df['titulo'].str.replace('autob\?s', 'autobús')
df['titulo'] = df['titulo'].str.replace('Am\?rica', 'América')

df['autor'] = df['autor'].str.replace('Virgi\?o', 'Virgilio')
df['autor'] = df['autor'].str.replace('Carli\?a', 'Carlia')
df['autor'] = df['autor'].str.replace('Due\?as', 'Dueñas')
df['autor'] = df['autor'].str.replace('Mu\?oz', 'Muñoz')
df['autor'] = df['autor'].str.replace('Noeli\?a', 'Noelia')
df['autor'] = df['autor'].str.replace('\?lvarez', 'Álvarez')
df['autor'] = df['autor'].str.replace('Cloti\?a', 'Clotia')
df['autor'] = df['autor'].str.replace('Agusti\?o', 'Agustín')
df['autor'] = df['autor'].str.replace('de la Luna Mu\?iz', 'de la Luna Muñiz')
df['autor'] = df['autor'].str.replace('de los \?ngeles Mu\?oz', 'de los Ángeles Muñoz')
df['autor'] = df['autor'].str.replace('Ordo\?ez', 'Ordoñez')
df['autor'] = df['autor'].str.replace('Daniel Pa\?ez', 'Daniel Páez')
df['autor'] = df['autor'].str.replace('E.C.\?', 'E.C.Ñ.')
df['autor'] = df['autor'].str.replace('Ovidi\?a', 'Ovidia')
df['autor'] = df['autor'].str.replace('Azucena Nu\?ez', 'Azucena Nuñez')
df['autor'] = df['autor'].str.replace('Clori\?a', 'Cloria')
df['autor'] = df['autor'].str.replace('Dani\?o', 'Danio')
df['autor'] = df['autor'].str.replace('Patri\?a', 'Patria')
df['autor'] = df['autor'].str.replace('Staples \?avincopa', 'Staples Navincopa')
df['autor'] = df['autor'].str.replace('Domi\?o', 'Dominio')
df['autor'] = df['autor'].str.replace('Maria de los \?ngeles Muñoz', 'Maria de los Ángeles Muñoz')
df['autor'] = df['autor'].str.replace('Ag\?ero', 'Agüero')
df['autor'] = df['autor'].str.replace('Mauri\?a', 'Mauricia')
df['autor'] = df['autor'].str.replace('Bauti\?o', 'Bautiño')
df['autor'] = df['autor'].str.replace('\?anez', 'Cáñez')
df['autor'] = df['autor'].str.replace('\?ngeles', 'Ángeles')
df['autor'] = df['autor'].str.replace('Verdi\?a', 'Verdía')
df['autor'] = df['autor'].str.replace('Yuri\?o', 'Yuriño')
df['autor'] = df['autor'].str.replace('Dari\?o', 'Darío')
df['autor'] = df['autor'].str.replace('Mu\?ante', 'Muñante')
df['autor'] = df['autor'].str.replace('\?vila', 'Ávila')
df['autor'] = df['autor'].str.replace('Prisci\?a', 'Priscila')
df['autor'] = df['autor'].str.replace('Rodri\?o', 'Rodrigo')
df['autor'] = df['autor'].str.replace('Placi\?o', 'Placio')
df['autor'] = df['autor'].str.replace('Berti\?a', 'Bertiza')
df['autor'] = df['autor'].str.replace('P.P.\?.', 'P.P.A.')
df['autor'] = df['autor'].str.replace('Elvi\?a', 'Elvia')
df['autor'] = df['autor'].str.replace('Mari\?o', 'Mariño')

df.to_csv('/Users/josedavidricodias/Downloads/Music_dumps/temas_filtered.csv')
# Out:
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_64728/2354173522.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['autor'] = df['autor'].str.replace('Virgi\?o', 'Virgilio')
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_64728/2354173522.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['autor'] = df['autor'].str.replace('Carli\?a', 'Carlia')
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_64728/2354173522.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['autor'] = df['autor'].str.replace('Due\?as', 'Dueñas')
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_64728/2354173522.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['autor'] = df['autor'].str.replace('Mu\?oz', 'Muñoz')
# ...

# %%
# Look for malformed words in a column of the CSV
bad_names = df[df['autor'].str.contains("\?")]['autor'].values # Change column names to check 1029412 -> 1029412	The '05 of youngster Tour	Wenceslao_	24/07/05	Mistvalley	Russian Federation	105	\N	\N	\N	\N	\N
bad_names
# Out:
# array([], dtype=object)

# %%
import re
p = re.compile('([\w\.]*\?[\w\.]*)')

words = [p.findall(s) for s in bad_names]

words = list(set([item for sublist in words for item in sublist]))
words
# Out:
# []

# %%
# Generate the python code to copy-paste
res = []
corrected_words = ['Matiño', 'Maxia', 'Pacía', 'Abrío', 'Ocampo Ocaña', 'Raúl Páez', 'Obdulia Muñayco', 'Alciño', 'Barriño', 'Fabiño', 'Bettía', 'Agustín Ramón Ocaña-Arensibia'] # This comes from ChatGPT

for index, value in enumerate(words):
    res.append("df['autor'] = df['autor'].str.replace('"+str(value).replace('?', ""+'\\?')+"', '"+corrected_words[index]+"')")

for result in res:
    print(result)

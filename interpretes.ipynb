# %%
import pandas as pd
pd.set_option('display.max_rows', None)
from numpy import where

# %% [markdown]
# ### Loop the data lines
# for file_number in range(1, 23+1):
#     with open('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', 'r') as temp_f:
#         # get No of columns in each line
#         col_count = [ len(l.split(",")) for l in temp_f.readlines() ]
#
#     ### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
#     column_names = ['COLUMN_'+str(i) for i in range(0, max(col_count))]
#
#     ### Read csv
#     df = pd.read_csv('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'.csv', header=None, delimiter=",", names=column_names)
#
#     df = df.drop(0)
#
#     df['COLUMN_12'] = df.query("not COLUMN_11.isnull()")['COLUMN_5'] + " " + df.query("not COLUMN_11.isnull()")['COLUMN_4'].str.replace('\\', '')
#     df['COLUMN_12'] = df['COLUMN_12'].str.replace('_', '\'')
#     df['COLUMN_4'] = where(df['COLUMN_12'].isnull(), df['COLUMN_4'], df['COLUMN_12'])
#
#     df['COLUMN_5'] = where(df['COLUMN_12'].isnull(), df['COLUMN_5'], df['COLUMN_6'])
#     df['COLUMN_6'] = where(df['COLUMN_12'].isnull(), df['COLUMN_6'], df['COLUMN_7'])
#     df['COLUMN_7'] = where(df['COLUMN_12'].isnull(), df['COLUMN_7'], df['COLUMN_8'])
#     df['COLUMN_8'] = where(df['COLUMN_12'].isnull(), df['COLUMN_8'], df['COLUMN_9'])
#     df['COLUMN_9'] = where(df['COLUMN_12'].isnull(), df['COLUMN_9'], df['COLUMN_10'])
#     df['COLUMN_10'] = where(df['COLUMN_12'].isnull(), df['COLUMN_10'], df['COLUMN_11'])
#     df.drop(columns=['COLUMN_11', 'COLUMN_12'], inplace=True)
#
#     df = df.rename(columns={'COLUMN_0': 'gira','COLUMN_1': 'interprete_o_banda', 'COLUMN_2': 'fecha', 'COLUMN_3': 'lugar', 'COLUMN_4': 'pais', 'COLUMN_5': 'duracion_total', 'COLUMN_6': 'orden', 'COLUMN_7': 'tema', 'COLUMN_8': 'pasaporte_miembro', 'COLUMN_9': 'miembro', 'COLUMN_10': 'duracion'})
#
#     df.to_csv('/Users/josedavidricodias/Downloads/Music_dumps/conciertos_'+str(file_number)+'_filtered.csv')

# %%
### Read csv
df = pd.read_csv('/Users/josedavidricodias/Downloads/Music_dumps/interpretes.csv', delimiter=",")

df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Carli\?a', 'Carliña')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Clori\?a', 'Cloriña')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Pa\?ez', 'Pañez')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Dani\?o', 'Daniño')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Ma\?anitas', 'Mañanitas')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Domi\?o', 'Domiño')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Cal\?', 'Calí')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('\?avincopa', 'Ñavincopa')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Cig\?e\?ales', 'Cigüeñales')

df['miembro'] = df['miembro'].str.replace('Virgi\?o', 'Virgilio')
df['miembro'] = df['miembro'].str.replace('Carli\?a', 'Carlia')
df['miembro'] = df['miembro'].str.replace('Due\?as', 'Dueñas')
df['miembro'] = df['miembro'].str.replace('Mu\?oz', 'Muñoz')
df['miembro'] = df['miembro'].str.replace('Noeli\?a', 'Noelia')
df['miembro'] = df['miembro'].str.replace('\?lvarez', 'Álvarez')
df['miembro'] = df['miembro'].str.replace('Cloti\?a', 'Clotia')
df['miembro'] = df['miembro'].str.replace('Agusti\?o', 'Agustín')
df['miembro'] = df['miembro'].str.replace('de la Luna Mu\?iz', 'de la Luna Muñiz')
df['miembro'] = df['miembro'].str.replace('de los \?ngeles Mu\?oz', 'de los Ángeles Muñoz')
df['miembro'] = df['miembro'].str.replace('Ordo\?ez', 'Ordoñez')
df['miembro'] = df['miembro'].str.replace('Daniel Pa\?ez', 'Daniel Páez')
df['miembro'] = df['miembro'].str.replace('E.C.\?', 'E.C.Ñ.')
df['miembro'] = df['miembro'].str.replace('Ovidi\?a', 'Ovidia')
df['miembro'] = df['miembro'].str.replace('Azucena Nu\?ez', 'Azucena Nuñez')
df['miembro'] = df['miembro'].str.replace('Clori\?a', 'Cloria')
df['miembro'] = df['miembro'].str.replace('Dani\?o', 'Danio')
df['miembro'] = df['miembro'].str.replace('Patri\?a', 'Patria')
df['miembro'] = df['miembro'].str.replace('Staples \?avincopa', 'Staples Navincopa')
df['miembro'] = df['miembro'].str.replace('Domi\?o', 'Dominio')
df['miembro'] = df['miembro'].str.replace('Maria de los \?ngeles Muñoz', 'Maria de los Ángeles Muñoz')
df['miembro'] = df['miembro'].str.replace('Ag\?ero', 'Agüero')
df['miembro'] = df['miembro'].str.replace('Mauri\?a', 'Mauricia')
df['miembro'] = df['miembro'].str.replace('Bauti\?o', 'Bautiño')
df['miembro'] = df['miembro'].str.replace('\?anez', 'Cáñez')
df['miembro'] = df['miembro'].str.replace('\?ngeles', 'Ángeles')
df['miembro'] = df['miembro'].str.replace('Verdi\?a', 'Verdía')
df['miembro'] = df['miembro'].str.replace('Yuri\?o', 'Yuriño')
df['miembro'] = df['miembro'].str.replace('Dari\?o', 'Darío')
df['miembro'] = df['miembro'].str.replace('Mu\?ante', 'Muñante')
df['miembro'] = df['miembro'].str.replace('\?vila', 'Ávila')
df['miembro'] = df['miembro'].str.replace('Prisci\?a', 'Priscila')
df['miembro'] = df['miembro'].str.replace('Rodri\?o', 'Rodrigo')
df['miembro'] = df['miembro'].str.replace('Placi\?o', 'Placio')
df['miembro'] = df['miembro'].str.replace('Berti\?a', 'Bertiza')
df['miembro'] = df['miembro'].str.replace('P.P.\?.', 'P.P.A.')
df['miembro'] = df['miembro'].str.replace('Elvi\?a', 'Elvia')
df['miembro'] = df['miembro'].str.replace('Mari\?o', 'Mariño')
df['miembro'] = df['miembro'].str.replace('Barri\?o', 'Barrito')
df['miembro'] = df['miembro'].str.replace('Paci\?a', 'Matiño')
df['miembro'] = df['miembro'].str.replace('Alci\?o', 'Maxia')
df['miembro'] = df['miembro'].str.replace('Barri\?o', 'Pacía')
df['miembro'] = df['miembro'].str.replace('Fabi\?o', 'Abrío')
df['miembro'] = df['miembro'].str.replace('Mati\?o', 'Ocampo Ocaña')
df['miembro'] = df['miembro'].str.replace('Maxi\?a', 'Raúl Páez')
df['miembro'] = df['miembro'].str.replace('Abri\?o', 'Obdulia Muñayco')
df['miembro'] = df['miembro'].str.replace('Oca\?a', 'Alciño')
df['miembro'] = df['miembro'].str.replace('Betti\?a', 'Barriño')
df['miembro'] = df['miembro'].str.replace('Pa\?ez', 'Fabiño')
df['miembro'] = df['miembro'].str.replace('Mu\?ayco', 'Bettía')

df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Due\?as', 'Dueñas')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Ag\?ero', 'Agüero')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Mauri\?a', 'Mauricia')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Lugare\?os', 'Lugareños')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('P\?jaros', 'Pájaros')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Par\?s', 'París')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Verdi\?a', 'Verdía')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('En\?logos', 'Enólogos')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Mu\?ante', 'Muñante')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('\?vila', 'Ávila')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Dari\?o', 'Darío')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Rodri\?o', 'Rodrigo')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Regardotop\?a', 'Regardotopía')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('P.P.\?.', 'P.P.A.')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Mu\?oz', 'Muñoz')
df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Barri\?o', 'Barrito')

df.to_csv('/Users/josedavidricodias/Downloads/Music_dumps/interpretes_filtered.csv')
# Out:
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_64147/2810928056.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Carli\?a', 'Carliña')
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_64147/2810928056.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Clori\?a', 'Cloriña')
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_64147/2810928056.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['interprete_o_banda'] = df['interprete_o_banda'].str.replace('Pa\?ez', 'Pañez')
# /var/folders/2b/sn9pm__s4xq2pw_dts6nk3y00000gn/T/ipykernel_64147/2810928056.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %%
# Look for malformed words in a column of the CSV
bad_names = df[df['interprete_o_banda'].str.contains("\?")]['interprete_o_banda'].values # Change column names to check 1029412 -> 1029412	The '05 of youngster Tour	Wenceslao_	24/07/05	Mistvalley	Russian Federation	105	\N	\N	\N	\N	\N
bad_names
# Out:
# array([], dtype=object)

# %%
import re
p = re.compile('([\w\.]*\?[\w\.]*)')

words = [p.findall(s) for s in bad_names]

words = list(set([item for sublist in words for item in sublist]))
words
# Out:
# []

# %%
# Generate the python code to copy-paste
res = []
corrected_words = ['Matiño', 'Maxia', 'Pacía', 'Abrío', 'Ocampo Ocaña', 'Raúl Páez', 'Obdulia Muñayco', 'Alciño', 'Barriño', 'Fabiño', 'Bettía', 'Agustín Ramón Ocaña-Arensibia'] # This comes from ChatGPT

for index, value in enumerate(words):
    res.append("df['miembro'] = df['miembro'].str.replace('"+str(value).replace('?', ""+'\\?')+"', '"+corrected_words[index]+"')")

for result in res:
    print(result)
